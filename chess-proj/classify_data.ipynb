# %%
import chess.pgn
import os
import json
import math
import time

# ================= 配置区域 =================
# 输入文件路径
INPUT_PGN_PATH = "dataset/lichess_db_standard_rated_2025-11.pgn"

# 输出根目录
OUTPUT_ROOT = "dataset/2025-11"

# 进度记录文件 (用于断点续传)
STATE_FILE = "dataset/process_state.json"

# 缓冲区大小 (局数): 积攒多少局游戏写一次硬盘
# 建议 5000 - 20000 之间，取决于你的内存
BUFFER_SIZE = 10000 
# ===========================================

def get_time_control_category(tc_tag):
    if tc_tag == "-" or not tc_tag:
        return "Unknown"
    
    try:
        if "+" in tc_tag:
            base, increment = tc_tag.split("+")
            base = int(base)
            increment = int(increment)
        else:
            base = int(tc_tag)
            increment = 0
            
        # Lichess 官方公式: 预计时长 = 基础时间 + 40 * 加秒
        estimated_duration = base + (40 * increment)
        
        # 严格参照 Lichess 源代码 (Speed.scala) 的阈值
        if estimated_duration < 180:   # < 3分钟 (180s)
            return "Bullet"
        elif estimated_duration < 480: # < 8分钟 (480s) [注意：之前很多标准是600，Lichess是480]
            return "Blitz"
        elif estimated_duration < 1500: # < 25分钟 (1500s)
            return "Rapid"
        else:
            return "Classical"      # >= 25分钟
    except:
        return "Unknown"

def get_elo_category(white_elo, black_elo):
    """
    计算平均分并返回分段字符串 (每200分为一段)
    """
    try:
        w = int(white_elo)
        b = int(black_elo)
        avg = (w + b) / 2
        
        # 向下取整到最近的 200 分
        # 例如 1550 -> 1400, 1601 -> 1600
        floor_val = math.floor(avg / 200) * 200
        return f"{floor_val}-{floor_val + 199}"
    except:
        return "Unrated"

def save_state(offset, games_processed):
    """保存当前进度到 JSON"""
    with open(STATE_FILE, "w") as f:
        json.dump({"offset": offset, "games_processed": games_processed}, f)

def load_state():
    """读取上次的进度"""
    if os.path.exists(STATE_FILE):
        with open(STATE_FILE, "r") as f:
            return json.load(f)
    return {"offset": 0, "games_processed": 0}

def flush_buffer(buffer_dict):
    """
    将缓冲区的数据写入磁盘
    buffer_dict 结构: { "Blitz/1400-1599": [game_str1, game_str2...], ... }
    """
    for key, games in buffer_dict.items():
        if not games:
            continue
            
        tc_cat, elo_cat = key.split("/")
        
        # 构建目录路径: dataset/2025-11/Blitz/1400-1599/
        dir_path = os.path.join(OUTPUT_ROOT, tc_cat, elo_cat)
        os.makedirs(dir_path, exist_ok=True)
        
        # 追加写入 games.pgn
        file_path = os.path.join(dir_path, "games.pgn")
        
        # 使用 'a' (append) 模式
        with open(file_path, "a", encoding="utf-8") as f:
            for game_str in games:
                f.write(game_str + "\n\n")

# ================= 主程序逻辑 =================

def process_pgn():
    # 1. 加载断点
    state = load_state()
    start_offset = state["offset"]
    total_games = state["games_processed"]
    
    print(f"--- 任务启动 ---")
    if start_offset > 0:
        print(f"发现断点记录，将从字节位置 {start_offset} (约已处理 {total_games} 局) 继续...")
    else:
        print("从头开始处理...")

    # 内存缓冲区
    game_buffer = {} # Key: "Category/Elo", Value: List of game strings
    current_batch_count = 0
    
    start_time = time.time()

    # 2. 打开大文件
    with open(INPUT_PGN_PATH, encoding="utf-8", errors="ignore") as pgn_file:
        # 如果有断点，直接跳转
        pgn_file.seek(start_offset)
        
        while True:
            # 记录读取这局游戏之前的文件指针位置
            # 注意：read_game 读取完后指针会在下一局开头，
            # 但我们需要保存的是"下一批次开始的位置"，所以我们在 flush 时保存 tell()
            
            try:
                # 读取一局
                game = chess.pgn.read_game(pgn_file)
            except Exception as e:
                print(f"读取出错 (跳过): {e}")
                continue

            if game is None:
                break # 文件结束
            
            # 提取元数据
            headers = game.headers
            tc = headers.get("TimeControl", "?")
            w_elo = headers.get("WhiteElo", "?")
            b_elo = headers.get("BlackElo", "?")
            
            # 分类
            tc_cat = get_time_control_category(tc)
            elo_cat = get_elo_category(w_elo, b_elo)
            
            dict_key = f"{tc_cat}/{elo_cat}"
            
            # 将游戏对象转回 PGN 字符串 (这是最耗时的步骤之一，但在保存为PGN时无法避免)
            # 使用 exporter 稍微快一点，且可以不输出复杂的评论如果不需要的话
            # 这里我们使用标准的 str(game) 保留所有信息
            game_str = str(game)
            
            # 加入缓冲区
            if dict_key not in game_buffer:
                game_buffer[dict_key] = []
            game_buffer[dict_key].append(game_str)
            
            current_batch_count += 1
            total_games += 1
            
            # 3. 缓冲区满，写入磁盘并保存进度
            if current_batch_count >= BUFFER_SIZE:
                flush_buffer(game_buffer)
                
                # 获取当前文件指针位置 (这就是新的断点)
                current_offset = pgn_file.tell()
                save_state(current_offset, total_games)
                
                # 打印进度
                elapsed = time.time() - start_time
                speed = current_batch_count / elapsed if elapsed > 0 else 0
                print(f"已处理: {total_games} 局 | 当前位置: {current_offset} | 速度: {speed:.1f} 局/秒")
                
                # 清空缓冲区
                game_buffer = {}
                current_batch_count = 0
                start_time = time.time() # 重置计时器以计算瞬时速度

    # 4. 处理剩余的缓冲区
    if current_batch_count > 0:
        print("正在写入剩余数据...")
        flush_buffer(game_buffer)
        save_state(pgn_file.tell(), total_games)
        
    print("--- 处理完成！所有的对局已分类保存 ---")

# 运行处理
if __name__ == "__main__":
    # 确保根目录存在
    if not os.path.exists("dataset"):
        os.makedirs("dataset")
        
    process_pgn()
# Out:
# --- 任务启动 ---
# 从头开始处理...
# 已处理: 10000 局 | 当前位置: 23390096 | 速度: 248.4 局/秒
# 已处理: 20000 局 | 当前位置: 46647498 | 速度: 160.3 局/秒
# 已处理: 30000 局 | 当前位置: 69946537 | 速度: 129.1 局/秒
# 已处理: 40000 局 | 当前位置: 93365941 | 速度: 166.1 局/秒
# 已处理: 50000 局 | 当前位置: 116671126 | 速度: 252.9 局/秒
# 已处理: 60000 局 | 当前位置: 139876851 | 速度: 222.8 局/秒
# 已处理: 70000 局 | 当前位置: 163042783 | 速度: 216.7 局/秒
# 已处理: 80000 局 | 当前位置: 186139906 | 速度: 213.9 局/秒
# 已处理: 90000 局 | 当前位置: 209358433 | 速度: 141.2 局/秒
# 已处理: 100000 局 | 当前位置: 232454088 | 速度: 215.6 局/秒
# 已处理: 110000 局 | 当前位置: 255822270 | 速度: 244.3 局/秒
# 已处理: 120000 局 | 当前位置: 279047204 | 速度: 248.0 局/秒
# 已处理: 130000 局 | 当前位置: 302207905 | 速度: 247.1 局/秒
# 已处理: 140000 局 | 当前位置: 325392959 | 速度: 233.2 局/秒
# 已处理: 150000 局 | 当前位置: 348585538 | 速度: 223.8 局/秒
# 已处理: 160000 局 | 当前位置: 371716288 | 速度: 220.4 局/秒
# 已处理: 170000 局 | 当前位置: 394858349 | 速度: 214.0 局/秒
# 已处理: 180000 局 | 当前位置: 418167404 | 速度: 221.8 局/秒
# 已处理: 190000 局 | 当前位置: 441309214 | 速度: 196.9 局/秒
# 已处理: 200000 局 | 当前位置: 464562259 | 速度: 208.4 局/秒
# 已处理: 210000 局 | 当前位置: 487823814 | 速度: 200.8 局/秒
# 已处理: 220000 局 | 当前位置: 511181676 | 速度: 245.1 局/秒
# 已处理: 230000 局 | 当前位置: 534336768 | 速度: 241.2 局/秒
# 已处理: 240000 局 | 当前位置: 557665431 | 速度: 230.7 局/秒
# 已处理: 250000 局 | 当前位置: 580844618 | 速度: 265.6 局/秒
# 已处理: 260000 局 | 当前位置: 604067690 | 速度: 238.6 局/秒
# 已处理: 270000 局 | 当前位置: 627282710 | 速度: 239.9 局/秒
# 已处理: 280000 局 | 当前位置: 650336538 | 速度: 243.6 局/秒
# 已处理: 290000 局 | 当前位置: 673512266 | 速度: 243.7 局/秒
# 已处理: 300000 局 | 当前位置: 696401029 | 速度: 239.6 局/秒
# 已处理: 310000 局 | 当前位置: 719425122 | 速度: 200.7 局/秒
# 已处理: 320000 局 | 当前位置: 742450618 | 速度: 189.0 局/秒
# 已处理: 330000 局 | 当前位置: 765268727 | 速度: 199.6 局/秒
# 已处理: 340000 局 | 当前位置: 788410145 | 速度: 214.7 局/秒
# 已处理: 350000 局 | 当前位置: 811484746 | 速度: 222.5 局/秒
# 已处理: 360000 局 | 当前位置: 834681279 | 速度: 210.0 局/秒
# 已处理: 370000 局 | 当前位置: 857861075 | 速度: 220.2 局/秒
# 已处理: 380000 局 | 当前位置: 880973782 | 速度: 219.3 局/秒
# 已处理: 390000 局 | 当前位置: 903933609 | 速度: 234.7 局/秒
# 已处理: 400000 局 | 当前位置: 927012681 | 速度: 232.5 局/秒
# 已处理: 410000 局 | 当前位置: 949891527 | 速度: 242.4 局/秒
# 已处理: 420000 局 | 当前位置: 972908988 | 速度: 235.1 局/秒
# 已处理: 430000 局 | 当前位置: 995887221 | 速度: 251.8 局/秒
# 已处理: 440000 局 | 当前位置: 1019069118 | 速度: 222.6 局/秒
# 已处理: 450000 局 | 当前位置: 1041949050 | 速度: 176.8 局/秒
# 已处理: 460000 局 | 当前位置: 1064896707 | 速度: 221.7 局/秒
# 已处理: 470000 局 | 当前位置: 1087985008 | 速度: 227.8 局/秒
# 已处理: 480000 局 | 当前位置: 1111052670 | 速度: 238.0 局/秒
# 已处理: 490000 局 | 当前位置: 1134136790 | 速度: 244.3 局/秒
# 已处理: 500000 局 | 当前位置: 1157033022 | 速度: 240.0 局/秒
# 已处理: 510000 局 | 当前位置: 1180012752 | 速度: 213.1 局/秒
# 已处理: 520000 局 | 当前位置: 1203071122 | 速度: 193.1 局/秒
# 已处理: 530000 局 | 当前位置: 1226016832 | 速度: 139.9 局/秒
# 已处理: 540000 局 | 当前位置: 1249201656 | 速度: 144.0 局/秒
# 已处理: 550000 局 | 当前位置: 1272158635 | 速度: 126.1 局/秒
# 已处理: 560000 局 | 当前位置: 1295310043 | 速度: 161.7 局/秒
# 已处理: 570000 局 | 当前位置: 1318453870 | 速度: 200.6 局/秒
# 已处理: 580000 局 | 当前位置: 1341470239 | 速度: 252.8 局/秒
# 已处理: 590000 局 | 当前位置: 1364663613 | 速度: 264.0 局/秒
# 已处理: 600000 局 | 当前位置: 1387828917 | 速度: 199.0 局/秒
# 已处理: 610000 局 | 当前位置: 1410899584 | 速度: 211.8 局/秒
# 已处理: 620000 局 | 当前位置: 1434112776 | 速度: 182.8 局/秒
# 已处理: 630000 局 | 当前位置: 1457363540 | 速度: 197.8 局/秒
# 已处理: 640000 局 | 当前位置: 1480689819 | 速度: 215.1 局/秒
# 已处理: 650000 局 | 当前位置: 1503949607 | 速度: 205.3 局/秒
# 已处理: 660000 局 | 当前位置: 1527085184 | 速度: 198.2 局/秒
# 已处理: 670000 局 | 当前位置: 1550244282 | 速度: 180.8 局/秒
# 已处理: 680000 局 | 当前位置: 1573525442 | 速度: 218.9 局/秒
# 已处理: 690000 局 | 当前位置: 1596776337 | 速度: 210.0 局/秒
# 已处理: 700000 局 | 当前位置: 1620186805 | 速度: 194.9 局/秒
# 已处理: 710000 局 | 当前位置: 1643419376 | 速度: 231.2 局/秒
# 已处理: 720000 局 | 当前位置: 1666678496 | 速度: 240.9 局/秒
# 已处理: 730000 局 | 当前位置: 1689903219 | 速度: 223.5 局/秒
# 已处理: 740000 局 | 当前位置: 1713140209 | 速度: 186.9 局/秒
# 已处理: 750000 局 | 当前位置: 1736334104 | 速度: 205.2 局/秒
# 已处理: 760000 局 | 当前位置: 1759652989 | 速度: 180.8 局/秒
# 已处理: 770000 局 | 当前位置: 1783032209 | 速度: 191.0 局/秒
# 已处理: 780000 局 | 当前位置: 1806166118 | 速度: 191.2 局/秒
# 已处理: 790000 局 | 当前位置: 1829452285 | 速度: 205.1 局/秒
# 已处理: 800000 局 | 当前位置: 1852683275 | 速度: 198.2 局/秒
# 已处理: 810000 局 | 当前位置: 1875876475 | 速度: 132.5 局/秒
# 已处理: 820000 局 | 当前位置: 1898945476 | 速度: 190.4 局/秒
# 已处理: 830000 局 | 当前位置: 1922133861 | 速度: 249.3 局/秒
# 已处理: 840000 局 | 当前位置: 1945173881 | 速度: 219.4 局/秒
# 已处理: 850000 局 | 当前位置: 1968415215 | 速度: 222.5 局/秒
# 已处理: 860000 局 | 当前位置: 1991590957 | 速度: 230.1 局/秒
# 已处理: 870000 局 | 当前位置: 2014746986 | 速度: 220.2 局/秒
# 已处理: 880000 局 | 当前位置: 2037889311 | 速度: 188.4 局/秒
# 已处理: 890000 局 | 当前位置: 2061143147 | 速度: 192.9 局/秒
# 已处理: 900000 局 | 当前位置: 2084323417 | 速度: 152.6 局/秒
# 已处理: 910000 局 | 当前位置: 2107597165 | 速度: 239.9 局/秒
# 已处理: 920000 局 | 当前位置: 2130909815 | 速度: 231.5 局/秒
# 已处理: 930000 局 | 当前位置: 2154093834 | 速度: 217.3 局/秒
# 已处理: 940000 局 | 当前位置: 2177313036 | 速度: 226.8 局/秒
# 已处理: 950000 局 | 当前位置: 2200501189 | 速度: 258.7 局/秒
# 已处理: 960000 局 | 当前位置: 2223815755 | 速度: 174.3 局/秒
# 已处理: 970000 局 | 当前位置: 2247025625 | 速度: 145.4 局/秒
# 已处理: 980000 局 | 当前位置: 2270209037 | 速度: 152.0 局/秒
# 已处理: 990000 局 | 当前位置: 2293302537 | 速度: 216.5 局/秒
# 已处理: 1000000 局 | 当前位置: 2316571327 | 速度: 209.1 局/秒
# 已处理: 1010000 局 | 当前位置: 2339852790 | 速度: 209.6 局/秒
# 已处理: 1020000 局 | 当前位置: 2363116231 | 速度: 261.8 局/秒
# 已处理: 1030000 局 | 当前位置: 2386223488 | 速度: 286.7 局/秒
# 已处理: 1040000 局 | 当前位置: 2409672028 | 速度: 162.4 局/秒
# 已处理: 1050000 局 | 当前位置: 2432953511 | 速度: 168.2 局/秒
# 已处理: 1060000 局 | 当前位置: 2456166374 | 速度: 171.2 局/秒
# 已处理: 1070000 局 | 当前位置: 2479313965 | 速度: 274.7 局/秒
# 已处理: 1080000 局 | 当前位置: 2502394484 | 速度: 261.9 局/秒
# 已处理: 1090000 局 | 当前位置: 2525719205 | 速度: 232.2 局/秒
# 已处理: 1100000 局 | 当前位置: 2548891452 | 速度: 245.2 局/秒
# 已处理: 1110000 局 | 当前位置: 2572176543 | 速度: 244.8 局/秒
# 已处理: 1120000 局 | 当前位置: 2595384605 | 速度: 239.5 局/秒
# 已处理: 1130000 局 | 当前位置: 2618670719 | 速度: 264.0 局/秒
# 已处理: 1140000 局 | 当前位置: 2641668862 | 速度: 204.5 局/秒
# 已处理: 1150000 局 | 当前位置: 2664889512 | 速度: 138.0 局/秒
# 已处理: 1160000 局 | 当前位置: 2688185045 | 速度: 189.7 局/秒
# 已处理: 1170000 局 | 当前位置: 2711320542 | 速度: 156.4 局/秒
# 已处理: 1180000 局 | 当前位置: 2734503535 | 速度: 266.2 局/秒
# 已处理: 1190000 局 | 当前位置: 2757735255 | 速度: 263.0 局/秒
# 已处理: 1200000 局 | 当前位置: 2780999812 | 速度: 155.5 局/秒
# 已处理: 1210000 局 | 当前位置: 2804240455 | 速度: 161.2 局/秒
# 已处理: 1220000 局 | 当前位置: 2827420085 | 速度: 180.1 局/秒
# 已处理: 1230000 局 | 当前位置: 2850495097 | 速度: 261.6 局/秒
# 已处理: 1240000 局 | 当前位置: 2873493326 | 速度: 242.5 局/秒
# 已处理: 1250000 局 | 当前位置: 2896695106 | 速度: 140.0 局/秒
# 已处理: 1260000 局 | 当前位置: 2919752794 | 速度: 197.4 局/秒
# 已处理: 1270000 局 | 当前位置: 2943094906 | 速度: 254.1 局/秒
# 已处理: 1280000 局 | 当前位置: 2966265231 | 速度: 241.1 局/秒
# 已处理: 1290000 局 | 当前位置: 2989549401 | 速度: 234.1 局/秒
# 已处理: 1300000 局 | 当前位置: 3012682204 | 速度: 280.6 局/秒
# 已处理: 1310000 局 | 当前位置: 3035812563 | 速度: 251.7 局/秒
# 已处理: 1320000 局 | 当前位置: 3059092087 | 速度: 272.7 局/秒
# 已处理: 1330000 局 | 当前位置: 3082277724 | 速度: 244.4 局/秒
# 已处理: 1340000 局 | 当前位置: 3105395658 | 速度: 267.7 局/秒
# 已处理: 1350000 局 | 当前位置: 3128579764 | 速度: 276.3 局/秒
# 已处理: 1360000 局 | 当前位置: 3151762988 | 速度: 262.3 局/秒
# 已处理: 1370000 局 | 当前位置: 3174992562 | 速度: 263.0 局/秒
# 已处理: 1380000 局 | 当前位置: 3198157732 | 速度: 249.8 局/秒
# 已处理: 1390000 局 | 当前位置: 3221409102 | 速度: 235.0 局/秒
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 198
#     195 if not os.path.exists("dataset"):
#     196     os.makedirs("dataset")
# --> 198 process_pgn()
#
# Cell In[1], line 156, in process_pgn()
#     151 dict_key = f"{tc_cat}/{elo_cat}"
#     153 # 将游戏对象转回 PGN 字符串 (这是最耗时的步骤之一，但在保存为PGN时无法避免)
#     154 # 使用 exporter 稍微快一点，且可以不输出复杂的评论如果不需要的话
#     155 # 这里我们使用标准的 str(game) 保留所有信息
# --> 156 game_str = str(game)
#     158 # 加入缓冲区
#     159 if dict_key not in game_buffer:
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\pgn.py:652, in GameNode.__str__(self)
#     651 def __str__(self) -> str:
# --> 652     return self.accept(StringExporter(columns=None))
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\pgn.py:892, in Game.accept(self, visitor)
#     889             visitor.visit_comment(self.comment)
#     891         if self.variations:
# --> 892             self.variations[0]._accept(board, visitor)
#     894         visitor.visit_result(self.headers.get("Result", "*"))
#     896 visitor.end_game()
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\pgn.py:770, in ChildNode._accept(self, parent_board, visitor, sidelines)
#     767     visitor.end_variation()
#     769 if top.state == "pre":
# --> 770     top.node._accept_node(parent_board, visitor)
#     771     top.state = "variations"
#     772 elif top.state == "variations":
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\pgn.py:747, in ChildNode._accept_node(self, parent_board, visitor)
#     744 if self.starting_comment:
#     745     visitor.visit_comment(self.starting_comment)
# --> 747 visitor.visit_move(parent_board, self.move)
#     749 parent_board.push(self.move)
#     750 visitor.visit_board(parent_board)
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\pgn.py:1420, in StringExporterMixin.visit_move(self, board, move)
#    1417     self.write_token(str(board.fullmove_number) + "... ")
#    1419 # Write the SAN.
# -> 1420 self.write_token(board.san(move) + " ")
#    1422 self.force_movenumber = False
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\__init__.py:2986, in Board.san(self, move)
#    2981 def san(self, move: Move) -> str:
#    2982     """
#    2983     Gets the standard algebraic notation of the given move in the context
#    2984     of the current position.
#    2985     """
# -> 2986     return self._algebraic(move)
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\__init__.py:2999, in Board._algebraic(self, move, long)
#    2998 def _algebraic(self, move: Move, *, long: bool = False) -> str:
# -> 2999     san = self._algebraic_and_push(move, long=long)
#    3000     self.pop()
#    3001     return san
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\__init__.py:3008, in Board._algebraic_and_push(self, move, long)
#    3006 # Look ahead for check or checkmate.
#    3007 self.push(move)
# -> 3008 is_check = self.is_check()
#    3009 is_checkmate = (is_check and self.is_checkmate()) or self.is_variant_loss() or self.is_variant_win()
#    3011 # Add check or checkmate suffix.
#
# File d:\conda_envs\notebook\Lib\site-packages\chess\__init__.py:1920, in Board.is_check(self)
#    1918 def is_check(self) -> bool:
#    1919     """Tests if the current side to move is in check."""
# -> 1920     return bool(self.checkers_mask())
#
# KeyboardInterrupt:
