# %% [markdown]
# # Chess Killer 2.0

# %%
import chess
import chess.pgn
import json
import os
import time
from collections import defaultdict

# ================= 配置区域 =================
PGN_FILE_PATH = "dataset/lichess_db_standard_rated_2025-11.pgn"
OUTCOME_DIR = "outcome/chess_killer"
CHECKPOINT_FILE = os.path.join(OUTCOME_DIR, "checkpoint_v2.json")
FINAL_RESULT_FILE = os.path.join(OUTCOME_DIR, "final_matrix.json")

# 统计上限回合数 (索引0-74对应1-75回合，索引75对应76+回合)
MAX_TURN_INDEX = 75 
SAVE_INTERVAL = 10000  # 每处理多少局保存一次
# ===========================================

class AdvancedTracker:
    def __init__(self):
        self.board_map = [None] * 64
        self.initialize_ids()

    def initialize_ids(self):
        files = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h']
        # 初始化逻辑与之前相同，确保每个棋子有唯一ID
        # White
        self.board_map[chess.A1] = {"id": "White_Rook_a", "promoted": False}
        self.board_map[chess.B1] = {"id": "White_Knight_b", "promoted": False}
        self.board_map[chess.C1] = {"id": "White_Bishop_c", "promoted": False}
        self.board_map[chess.D1] = {"id": "White_Queen", "promoted": False}
        self.board_map[chess.E1] = {"id": "White_King", "promoted": False}
        self.board_map[chess.F1] = {"id": "White_Bishop_f", "promoted": False}
        self.board_map[chess.G1] = {"id": "White_Knight_g", "promoted": False}
        self.board_map[chess.H1] = {"id": "White_Rook_h", "promoted": False}
        for i, f in enumerate(files):
            self.board_map[chess.A2 + i] = {"id": f"White_Pawn_{f}", "promoted": False}

        # Black
        self.board_map[chess.A8] = {"id": "Black_Rook_a", "promoted": False}
        self.board_map[chess.B8] = {"id": "Black_Knight_b", "promoted": False}
        self.board_map[chess.C8] = {"id": "Black_Bishop_c", "promoted": False}
        self.board_map[chess.D8] = {"id": "Black_Queen", "promoted": False}
        self.board_map[chess.E8] = {"id": "Black_King", "promoted": False}
        self.board_map[chess.F8] = {"id": "Black_Bishop_f", "promoted": False}
        self.board_map[chess.G8] = {"id": "Black_Knight_g", "promoted": False}
        self.board_map[chess.H8] = {"id": "Black_Rook_h", "promoted": False}
        for i, f in enumerate(files):
            self.board_map[chess.A7 + i] = {"id": f"Black_Pawn_{f}", "promoted": False}

    def get_full_id(self, piece_data):
        if piece_data is None: return None
        suffix = "_promoted" if piece_data['promoted'] else ""
        return f"{piece_data['id']}{suffix}"

def get_turn_index(board_fullmove):
    # 回合数从1开始。Index 0 对应 Turn 1.
    # 如果超过75回合，归入 index 75
    idx = board_fullmove - 1
    if idx < 0: idx = 0 # 防御性编程
    if idx > MAX_TURN_INDEX: idx = MAX_TURN_INDEX
    return idx

def update_stats(stats, attacker_id, victim_id, turn_idx):
    """
    更新全局统计数据 (3D Matrix)
    """
    # 1. 更新 Kill Matrix: attacker -> victim -> turn
    if attacker_id not in stats["kill_matrix"]:
        stats["kill_matrix"][attacker_id] = {}
    
    if victim_id not in stats["kill_matrix"][attacker_id]:
        # 初始化一个长度为 MAX_TURN_INDEX + 1 的数组
        stats["kill_matrix"][attacker_id][victim_id] = [0] * (MAX_TURN_INDEX + 1)
    
    stats["kill_matrix"][attacker_id][victim_id][turn_idx] += 1

    # 2. 更新 Death Timeline: victim -> turn
    if victim_id not in stats["death_timeline"]:
        stats["death_timeline"][victim_id] = [0] * (MAX_TURN_INDEX + 1)
    
    stats["death_timeline"][victim_id][turn_idx] += 1

def process_game_moves(game, stats):
    board = game.board()
    tracker = AdvancedTracker()

    for move in game.mainline_moves():
        from_sq = move.from_square
        to_sq = move.to_square
        
        attacker_data = tracker.board_map[from_sq]
        if attacker_data is None: 
            board.push(move)
            continue # 数据异常跳过

        attacker_id = tracker.get_full_id(attacker_data)
        turn_idx = get_turn_index(board.fullmove_number)

        # --- 1. 处理吃子 (Physical Capture) ---
        if board.is_capture(move):
            victim_data = None
            
            if board.is_en_passant(move):
                # 吃过路兵：受害者在旁边
                offset = -8 if board.turn == chess.WHITE else 8
                victim_sq = to_sq + offset
                victim_data = tracker.board_map[victim_sq]
                # 移除被吃掉的兵
                tracker.board_map[victim_sq] = None
            else:
                # 普通吃子
                victim_data = tracker.board_map[to_sq]

            if victim_data:
                victim_id = tracker.get_full_id(victim_data)
                update_stats(stats, attacker_id, victim_id, turn_idx)

        # --- 2. 移动 Tracker 逻辑 ---
        # 处理易位
        if board.is_castling(move):
            if to_sq == chess.G1:   # White K-side
                tracker.board_map[chess.F1] = tracker.board_map[chess.H1]
                tracker.board_map[chess.H1] = None
            elif to_sq == chess.C1: # White Q-side
                tracker.board_map[chess.D1] = tracker.board_map[chess.A1]
                tracker.board_map[chess.A1] = None
            elif to_sq == chess.G8: # Black K-side
                tracker.board_map[chess.F8] = tracker.board_map[chess.H8]
                tracker.board_map[chess.H8] = None
            elif to_sq == chess.C8: # Black Q-side
                tracker.board_map[chess.D8] = tracker.board_map[chess.A8]
                tracker.board_map[chess.A8] = None
        
        # 移动棋子
        tracker.board_map[to_sq] = attacker_data
        tracker.board_map[from_sq] = None

        # 处理升变
        if move.promotion:
            tracker.board_map[to_sq]['promoted'] = True

        # 在逻辑棋盘落子 (必须先 update tracker 再 push，否则判断过路兵位置会麻烦)
        board.push(move)

        # --- 3. 处理将杀 (Checkmate as a Kill) ---
        if board.is_checkmate():
            # 此时 attacker_data 已经在 to_sq (如果不是升变)
            # 注意：如果刚才这步是升变，Attacker ID 应该变成 promoted 吗？
            # 逻辑上：兵到底线变后后将杀，应该是 "White_Pawn_a_promoted" 杀了王。
            # 我们重新获取一次 id，确保状态最新
            final_attacker_data = tracker.board_map[to_sq]
            final_attacker_id = tracker.get_full_id(final_attacker_data)
            
            # 受害者是对方的王
            opponent_king_color = "Black" if board.turn == chess.WHITE else "White" 
            # board.turn 在 push 后已经变了，如果现在是 White 走，说明刚才 Black 杀的
            # 哎呀，board.push(move) 之后，轮次已经交给对方了。
            # 如果 board.is_checkmate() 为真，说明当前轮次方无法动弹，被上一手方杀死了。
            
            loser_color = "White" if board.turn == chess.WHITE else "Black"
            victim_id = f"{loser_color}_King" 
            
            # 记录虚空击杀
            update_stats(stats, final_attacker_id, victim_id, turn_idx)

def run_advanced_analysis():
    if not os.path.exists(OUTCOME_DIR):
        os.makedirs(OUTCOME_DIR)

    # 数据结构初始化
    stats = {
        "kill_matrix": {},    # 3D: Attacker -> Victim -> [Turn Counts]
        "death_timeline": {}  # 2D: Victim -> [Turn Counts]
    }
    games_processed = 0
    file_offset = 0

    # 断点续传
    if os.path.exists(CHECKPOINT_FILE):
        print(f"Loading checkpoint: {CHECKPOINT_FILE}")
        try:
            with open(CHECKPOINT_FILE, 'r') as f:
                data = json.load(f)
                stats = data.get("stats", stats)
                games_processed = data.get("games_processed", 0)
                file_offset = data.get("current_pgn_offset", 0)
            print(f"Resuming from Game {games_processed}, Offset {file_offset}")
        except Exception as e:
            print(f"Checkpoint load failed: {e}. Starting fresh.")

    if not os.path.exists(PGN_FILE_PATH):
        print("PGN file not found.")
        return

    print("Starting Advanced Analysis...")
    start_time = time.time()

    with open(PGN_FILE_PATH) as pgn_file:
        pgn_file.seek(file_offset)
        
        while True:
            try:
                # 记录这局开始前的偏移量，以便保存
                offset_before_game = pgn_file.tell()
                game = chess.pgn.read_game(pgn_file)
            except Exception:
                continue

            if game is None:
                break

            process_game_moves(game, stats)
            games_processed += 1

            if games_processed % SAVE_INTERVAL == 0:
                elapsed = time.time() - start_time
                print(f"Processed: {games_processed} | Time: {elapsed:.1f}s | Speed: {games_processed/elapsed:.1f} g/s")
                
                # 获取读完后的 offset
                current_offset = pgn_file.tell()
                
                checkpoint_data = {
                    "games_processed": games_processed,
                    "current_pgn_offset": current_offset,
                    "stats": stats
                }
                
                # 原子写入
                temp_path = CHECKPOINT_FILE + ".tmp"
                with open(temp_path, 'w') as f:
                    json.dump(checkpoint_data, f) # 这里不indent以节省空间和IO
                os.replace(temp_path, CHECKPOINT_FILE)

    # Final Save
    with open(FINAL_RESULT_FILE, 'w') as f:
        json.dump(stats, f, indent=4) # 最终结果格式化以便人类阅读
    print(f"Done! Saved to {FINAL_RESULT_FILE}")

if __name__ == "__main__":
    run_advanced_analysis()
# Out:
# Starting Advanced Analysis...
# Processed: 10000 | Time: 20.6s | Speed: 485.5 g/s
# Processed: 20000 | Time: 41.6s | Speed: 480.4 g/s
# Processed: 30000 | Time: 63.0s | Speed: 476.1 g/s
# Processed: 40000 | Time: 84.5s | Speed: 473.5 g/s
# Processed: 50000 | Time: 105.1s | Speed: 476.0 g/s
# Processed: 60000 | Time: 124.9s | Speed: 480.3 g/s
# Processed: 70000 | Time: 144.8s | Speed: 483.3 g/s
# Processed: 80000 | Time: 164.4s | Speed: 486.6 g/s
# Processed: 90000 | Time: 184.4s | Speed: 488.2 g/s
# Processed: 100000 | Time: 203.5s | Speed: 491.5 g/s
# Processed: 110000 | Time: 222.8s | Speed: 493.7 g/s
# Processed: 120000 | Time: 260.3s | Speed: 461.0 g/s
# Processed: 130000 | Time: 303.8s | Speed: 427.8 g/s
# Processed: 140000 | Time: 330.9s | Speed: 423.1 g/s
# Processed: 150000 | Time: 373.5s | Speed: 401.6 g/s
# Processed: 160000 | Time: 416.6s | Speed: 384.1 g/s
# Processed: 170000 | Time: 458.6s | Speed: 370.7 g/s
# Processed: 180000 | Time: 502.6s | Speed: 358.1 g/s
# Processed: 190000 | Time: 534.1s | Speed: 355.7 g/s
# Processed: 200000 | Time: 553.9s | Speed: 361.1 g/s
# Processed: 210000 | Time: 573.7s | Speed: 366.0 g/s
# Processed: 220000 | Time: 592.3s | Speed: 371.4 g/s
# Processed: 230000 | Time: 610.5s | Speed: 376.7 g/s
# Processed: 240000 | Time: 629.5s | Speed: 381.3 g/s
# Processed: 250000 | Time: 648.2s | Speed: 385.7 g/s
# Processed: 260000 | Time: 667.1s | Speed: 389.7 g/s
# Processed: 270000 | Time: 686.0s | Speed: 393.6 g/s
# Processed: 280000 | Time: 705.8s | Speed: 396.7 g/s
# Processed: 290000 | Time: 726.1s | Speed: 399.4 g/s
# Processed: 300000 | Time: 745.6s | Speed: 402.3 g/s
# Processed: 310000 | Time: 765.8s | Speed: 404.8 g/s
# Processed: 320000 | Time: 785.3s | Speed: 407.5 g/s
# Processed: 330000 | Time: 804.7s | Speed: 410.1 g/s
# Processed: 340000 | Time: 824.5s | Speed: 412.4 g/s
# Processed: 350000 | Time: 844.0s | Speed: 414.7 g/s
# Processed: 360000 | Time: 863.8s | Speed: 416.8 g/s
# Processed: 370000 | Time: 883.1s | Speed: 419.0 g/s
# Processed: 380000 | Time: 902.3s | Speed: 421.1 g/s
# Processed: 390000 | Time: 921.5s | Speed: 423.2 g/s
# Processed: 400000 | Time: 940.7s | Speed: 425.2 g/s
# Processed: 410000 | Time: 959.7s | Speed: 427.2 g/s
# Processed: 420000 | Time: 978.8s | Speed: 429.1 g/s
# Processed: 430000 | Time: 997.9s | Speed: 430.9 g/s
# Processed: 440000 | Time: 1017.3s | Speed: 432.5 g/s
# Processed: 450000 | Time: 1036.2s | Speed: 434.3 g/s
# Processed: 460000 | Time: 1055.2s | Speed: 435.9 g/s
# Processed: 470000 | Time: 1074.2s | Speed: 437.5 g/s
# Processed: 480000 | Time: 1093.3s | Speed: 439.1 g/s
# Processed: 490000 | Time: 1113.3s | Speed: 440.1 g/s
# Processed: 500000 | Time: 1133.9s | Speed: 441.0 g/s
# Processed: 510000 | Time: 1153.3s | Speed: 442.2 g/s
# Processed: 520000 | Time: 1173.3s | Speed: 443.2 g/s
# Processed: 530000 | Time: 1192.9s | Speed: 444.3 g/s
# Processed: 540000 | Time: 1214.2s | Speed: 444.7 g/s
# Processed: 550000 | Time: 1234.2s | Speed: 445.6 g/s
# Processed: 560000 | Time: 1254.1s | Speed: 446.5 g/s
# Processed: 570000 | Time: 1273.9s | Speed: 447.4 g/s
# Processed: 580000 | Time: 1293.7s | Speed: 448.3 g/s
# Processed: 590000 | Time: 1313.2s | Speed: 449.3 g/s
# Processed: 600000 | Time: 1332.5s | Speed: 450.3 g/s
# Processed: 610000 | Time: 1351.7s | Speed: 451.3 g/s
# Processed: 620000 | Time: 1371.0s | Speed: 452.2 g/s
# Processed: 630000 | Time: 1390.3s | Speed: 453.1 g/s
# Processed: 640000 | Time: 1409.5s | Speed: 454.1 g/s
# Processed: 650000 | Time: 1428.8s | Speed: 454.9 g/s
# Processed: 660000 | Time: 1448.0s | Speed: 455.8 g/s
# Processed: 670000 | Time: 1467.2s | Speed: 456.7 g/s
# Processed: 680000 | Time: 1486.4s | Speed: 457.5 g/s
# Processed: 690000 | Time: 1505.7s | Speed: 458.2 g/s
# Processed: 700000 | Time: 1525.2s | Speed: 459.0 g/s
# Processed: 710000 | Time: 1545.0s | Speed: 459.5 g/s
# Processed: 720000 | Time: 1564.4s | Speed: 460.2 g/s
# Processed: 730000 | Time: 1583.8s | Speed: 460.9 g/s
# Processed: 740000 | Time: 1603.3s | Speed: 461.6 g/s
# Processed: 750000 | Time: 1622.6s | Speed: 462.2 g/s
# Processed: 760000 | Time: 1642.1s | Speed: 462.8 g/s
# Processed: 770000 | Time: 1661.7s | Speed: 463.4 g/s
# Processed: 780000 | Time: 1681.1s | Speed: 464.0 g/s
# Processed: 790000 | Time: 1700.6s | Speed: 464.6 g/s
# Processed: 800000 | Time: 1720.0s | Speed: 465.1 g/s
# Processed: 810000 | Time: 1739.5s | Speed: 465.7 g/s
# Processed: 820000 | Time: 1758.7s | Speed: 466.3 g/s
# Processed: 830000 | Time: 1778.1s | Speed: 466.8 g/s
# Processed: 840000 | Time: 1797.5s | Speed: 467.3 g/s
# Processed: 850000 | Time: 1816.8s | Speed: 467.9 g/s
# Processed: 860000 | Time: 1836.1s | Speed: 468.4 g/s
# Processed: 870000 | Time: 1855.9s | Speed: 468.8 g/s
# Processed: 880000 | Time: 1875.5s | Speed: 469.2 g/s
# Processed: 890000 | Time: 1895.0s | Speed: 469.7 g/s
# Processed: 900000 | Time: 1914.3s | Speed: 470.1 g/s
# Processed: 910000 | Time: 1933.8s | Speed: 470.6 g/s
# Processed: 920000 | Time: 1953.7s | Speed: 470.9 g/s
# Processed: 930000 | Time: 1972.3s | Speed: 471.5 g/s
# Processed: 940000 | Time: 1990.8s | Speed: 472.2 g/s
# Processed: 950000 | Time: 2009.1s | Speed: 472.8 g/s
# Processed: 960000 | Time: 2027.6s | Speed: 473.5 g/s
# Processed: 970000 | Time: 2045.9s | Speed: 474.1 g/s
# Processed: 980000 | Time: 2064.4s | Speed: 474.7 g/s
# Processed: 990000 | Time: 2082.5s | Speed: 475.4 g/s
# Processed: 1000000 | Time: 2100.8s | Speed: 476.0 g/s
# Processed: 1010000 | Time: 2119.3s | Speed: 476.6 g/s
# Processed: 1020000 | Time: 2137.7s | Speed: 477.2 g/s
# Processed: 1030000 | Time: 2155.8s | Speed: 477.8 g/s
# Processed: 1040000 | Time: 2174.4s | Speed: 478.3 g/s
# Processed: 1050000 | Time: 2192.8s | Speed: 478.9 g/s
# Processed: 1060000 | Time: 2211.0s | Speed: 479.4 g/s
# Processed: 1070000 | Time: 2229.3s | Speed: 480.0 g/s
# Processed: 1080000 | Time: 2247.6s | Speed: 480.5 g/s
# Processed: 1090000 | Time: 2266.1s | Speed: 481.0 g/s
# Processed: 1100000 | Time: 2284.5s | Speed: 481.5 g/s
# Processed: 1110000 | Time: 2303.6s | Speed: 481.9 g/s
# Processed: 1120000 | Time: 2323.2s | Speed: 482.1 g/s
# Processed: 1130000 | Time: 2342.8s | Speed: 482.3 g/s
# Processed: 1140000 | Time: 2362.4s | Speed: 482.6 g/s
# Processed: 1150000 | Time: 2381.7s | Speed: 482.8 g/s
# Processed: 1160000 | Time: 2401.1s | Speed: 483.1 g/s
# Processed: 1170000 | Time: 2420.4s | Speed: 483.4 g/s
# Processed: 1180000 | Time: 2439.7s | Speed: 483.7 g/s
# Processed: 1190000 | Time: 2459.1s | Speed: 483.9 g/s
# Processed: 1200000 | Time: 2478.3s | Speed: 484.2 g/s
# Processed: 1210000 | Time: 2497.6s | Speed: 484.5 g/s
# Processed: 1220000 | Time: 2516.7s | Speed: 484.8 g/s
# Processed: 1230000 | Time: 2535.7s | Speed: 485.1 g/s
# Processed: 1240000 | Time: 2554.6s | Speed: 485.4 g/s
# Processed: 1250000 | Time: 2573.6s | Speed: 485.7 g/s
# Processed: 1260000 | Time: 2592.9s | Speed: 485.9 g/s
# Processed: 1270000 | Time: 2612.3s | Speed: 486.2 g/s
# Processed: 1280000 | Time: 2631.4s | Speed: 486.4 g/s
# Processed: 1290000 | Time: 2650.8s | Speed: 486.7 g/s
# Processed: 1300000 | Time: 2670.0s | Speed: 486.9 g/s
# Processed: 1310000 | Time: 2689.3s | Speed: 487.1 g/s
# Processed: 1320000 | Time: 2708.6s | Speed: 487.3 g/s
# Processed: 1330000 | Time: 2727.9s | Speed: 487.6 g/s
# Processed: 1340000 | Time: 2747.1s | Speed: 487.8 g/s
# Processed: 1350000 | Time: 2766.5s | Speed: 488.0 g/s
# Processed: 1360000 | Time: 2785.8s | Speed: 488.2 g/s
# Processed: 1370000 | Time: 2805.2s | Speed: 488.4 g/s
# Processed: 1380000 | Time: 2824.4s | Speed: 488.6 g/s
# Processed: 1390000 | Time: 2843.7s | Speed: 488.8 g/s
# Processed: 1400000 | Time: 2862.9s | Speed: 489.0 g/s
# Processed: 1410000 | Time: 2882.0s | Speed: 489.2 g/s
# Processed: 1420000 | Time: 2901.0s | Speed: 489.5 g/s
# Processed: 1430000 | Time: 2920.1s | Speed: 489.7 g/s
# Processed: 1440000 | Time: 2939.1s | Speed: 489.9 g/s
# Processed: 1450000 | Time: 2958.1s | Speed: 490.2 g/s
# Processed: 1460000 | Time: 2977.3s | Speed: 490.4 g/s
# Processed: 1470000 | Time: 2996.5s | Speed: 490.6 g/s
# Processed: 1480000 | Time: 3015.8s | Speed: 490.8 g/s
# Processed: 1490000 | Time: 3035.0s | Speed: 490.9 g/s
# Processed: 1500000 | Time: 3054.2s | Speed: 491.1 g/s
# Processed: 1510000 | Time: 3073.4s | Speed: 491.3 g/s
# Processed: 1520000 | Time: 3092.7s | Speed: 491.5 g/s
# Processed: 1530000 | Time: 3111.7s | Speed: 491.7 g/s
# Processed: 1540000 | Time: 3130.9s | Speed: 491.9 g/s
# Processed: 1550000 | Time: 3150.3s | Speed: 492.0 g/s
# Processed: 1560000 | Time: 3169.6s | Speed: 492.2 g/s
# Processed: 1570000 | Time: 3188.8s | Speed: 492.4 g/s
# Processed: 1580000 | Time: 3208.1s | Speed: 492.5 g/s
# Processed: 1590000 | Time: 3227.1s | Speed: 492.7 g/s
# Processed: 1600000 | Time: 3246.0s | Speed: 492.9 g/s
# Processed: 1610000 | Time: 3265.2s | Speed: 493.1 g/s
# Processed: 1620000 | Time: 3284.3s | Speed: 493.3 g/s
# Processed: 1630000 | Time: 3303.4s | Speed: 493.4 g/s
# Processed: 1640000 | Time: 3322.8s | Speed: 493.6 g/s
# Processed: 1650000 | Time: 3342.0s | Speed: 493.7 g/s
# Processed: 1660000 | Time: 3361.3s | Speed: 493.9 g/s
# Processed: 1670000 | Time: 3380.5s | Speed: 494.0 g/s
# Processed: 1680000 | Time: 3399.8s | Speed: 494.1 g/s
# Processed: 1690000 | Time: 3419.1s | Speed: 494.3 g/s
# Processed: 1700000 | Time: 3438.4s | Speed: 494.4 g/s
# Processed: 1710000 | Time: 3457.7s | Speed: 494.5 g/s
# Processed: 1720000 | Time: 3476.8s | Speed: 494.7 g/s
# Processed: 1730000 | Time: 3496.1s | Speed: 494.8 g/s
# Processed: 1740000 | Time: 3515.5s | Speed: 495.0 g/s
# Processed: 1750000 | Time: 3534.8s | Speed: 495.1 g/s
# Processed: 1760000 | Time: 3554.1s | Speed: 495.2 g/s
# Processed: 1770000 | Time: 3573.3s | Speed: 495.3 g/s
# Processed: 1780000 | Time: 3592.6s | Speed: 495.5 g/s
# Processed: 1790000 | Time: 3611.8s | Speed: 495.6 g/s
# Processed: 1800000 | Time: 3631.0s | Speed: 495.7 g/s
# Processed: 1810000 | Time: 3650.2s | Speed: 495.9 g/s
# Processed: 1820000 | Time: 3669.6s | Speed: 496.0 g/s
# Processed: 1830000 | Time: 3689.0s | Speed: 496.1 g/s
# Processed: 1840000 | Time: 3708.3s | Speed: 496.2 g/s
# Processed: 1850000 | Time: 3727.8s | Speed: 496.3 g/s
# Processed: 1860000 | Time: 3747.1s | Speed: 496.4 g/s
# Processed: 1870000 | Time: 3766.4s | Speed: 496.5 g/s
# Processed: 1880000 | Time: 3785.8s | Speed: 496.6 g/s
# Processed: 1890000 | Time: 3805.2s | Speed: 496.7 g/s
# Processed: 1900000 | Time: 3824.5s | Speed: 496.8 g/s
# Processed: 1910000 | Time: 3843.8s | Speed: 496.9 g/s
# Processed: 1920000 | Time: 3863.3s | Speed: 497.0 g/s
# Processed: 1930000 | Time: 3882.7s | Speed: 497.1 g/s
# Processed: 1940000 | Time: 3902.1s | Speed: 497.2 g/s
# Processed: 1950000 | Time: 3921.2s | Speed: 497.3 g/s
# Processed: 1960000 | Time: 3940.4s | Speed: 497.4 g/s
# Processed: 1970000 | Time: 3959.3s | Speed: 497.6 g/s
# Processed: 1980000 | Time: 3978.3s | Speed: 497.7 g/s
# Processed: 1990000 | Time: 3997.2s | Speed: 497.8 g/s
# Processed: 2000000 | Time: 4016.4s | Speed: 498.0 g/s
# Processed: 2010000 | Time: 4035.7s | Speed: 498.1 g/s
# Processed: 2020000 | Time: 4054.9s | Speed: 498.2 g/s
# Processed: 2030000 | Time: 4074.0s | Speed: 498.3 g/s
# Processed: 2040000 | Time: 4093.3s | Speed: 498.4 g/s
# Processed: 2050000 | Time: 4112.6s | Speed: 498.5 g/s
# Processed: 2060000 | Time: 4131.9s | Speed: 498.6 g/s
# Processed: 2070000 | Time: 4151.2s | Speed: 498.7 g/s
# Processed: 2080000 | Time: 4170.4s | Speed: 498.7 g/s
# Processed: 2090000 | Time: 4189.7s | Speed: 498.8 g/s
# Processed: 2100000 | Time: 4209.0s | Speed: 498.9 g/s
# Processed: 2110000 | Time: 4228.3s | Speed: 499.0 g/s
# Processed: 2120000 | Time: 4247.5s | Speed: 499.1 g/s
# Processed: 2130000 | Time: 4266.8s | Speed: 499.2 g/s
# Processed: 2140000 | Time: 4286.0s | Speed: 499.3 g/s
# Processed: 2150000 | Time: 4305.3s | Speed: 499.4 g/s
# Processed: 2160000 | Time: 4324.6s | Speed: 499.5 g/s
# Processed: 2170000 | Time: 4343.8s | Speed: 499.6 g/s
# Processed: 2180000 | Time: 4362.9s | Speed: 499.7 g/s
# Processed: 2190000 | Time: 4382.2s | Speed: 499.8 g/s
# Processed: 2200000 | Time: 4401.4s | Speed: 499.8 g/s
# Processed: 2210000 | Time: 4420.9s | Speed: 499.9 g/s
# Processed: 2220000 | Time: 4440.3s | Speed: 500.0 g/s
# Processed: 2230000 | Time: 4459.7s | Speed: 500.0 g/s
# Processed: 2240000 | Time: 4479.1s | Speed: 500.1 g/s
# Processed: 2250000 | Time: 4498.7s | Speed: 500.1 g/s
# Processed: 2260000 | Time: 4518.1s | Speed: 500.2 g/s
# Processed: 2270000 | Time: 4537.5s | Speed: 500.3 g/s
# Processed: 2280000 | Time: 4557.0s | Speed: 500.3 g/s
# Processed: 2290000 | Time: 4576.4s | Speed: 500.4 g/s
# Processed: 2300000 | Time: 4595.9s | Speed: 500.4 g/s
# Processed: 2310000 | Time: 4615.4s | Speed: 500.5 g/s
# Processed: 2320000 | Time: 4634.9s | Speed: 500.5 g/s
# Processed: 2330000 | Time: 4654.3s | Speed: 500.6 g/s
# Processed: 2340000 | Time: 4673.7s | Speed: 500.7 g/s
# Processed: 2350000 | Time: 4693.2s | Speed: 500.7 g/s
# Processed: 2360000 | Time: 4712.6s | Speed: 500.8 g/s
# Processed: 2370000 | Time: 4732.1s | Speed: 500.8 g/s
# Processed: 2380000 | Time: 4751.6s | Speed: 500.9 g/s
# Processed: 2390000 | Time: 4771.1s | Speed: 500.9 g/s
# Processed: 2400000 | Time: 4790.6s | Speed: 501.0 g/s
# Processed: 2410000 | Time: 4810.1s | Speed: 501.0 g/s
# Processed: 2420000 | Time: 4829.6s | Speed: 501.1 g/s
# Processed: 2430000 | Time: 4849.2s | Speed: 501.1 g/s
# Processed: 2440000 | Time: 4868.8s | Speed: 501.2 g/s
# Processed: 2450000 | Time: 4888.4s | Speed: 501.2 g/s
# Processed: 2460000 | Time: 4907.9s | Speed: 501.2 g/s
# Processed: 2470000 | Time: 4927.6s | Speed: 501.3 g/s
# Processed: 2480000 | Time: 4947.0s | Speed: 501.3 g/s
# Processed: 2490000 | Time: 4966.4s | Speed: 501.4 g/s
# Processed: 2500000 | Time: 4985.9s | Speed: 501.4 g/s
# Processed: 2510000 | Time: 5005.4s | Speed: 501.5 g/s
# Processed: 2520000 | Time: 5024.9s | Speed: 501.5 g/s
# Processed: 2530000 | Time: 5044.2s | Speed: 501.6 g/s
# Processed: 2540000 | Time: 5063.6s | Speed: 501.6 g/s
# Processed: 2550000 | Time: 5082.8s | Speed: 501.7 g/s
# Processed: 2560000 | Time: 5102.4s | Speed: 501.7 g/s
# Processed: 2570000 | Time: 5122.0s | Speed: 501.8 g/s
# Processed: 2580000 | Time: 5141.5s | Speed: 501.8 g/s
# Processed: 2590000 | Time: 5161.0s | Speed: 501.8 g/s
# Processed: 2600000 | Time: 5180.6s | Speed: 501.9 g/s
# Processed: 2610000 | Time: 5200.1s | Speed: 501.9 g/s
# Processed: 2620000 | Time: 5219.7s | Speed: 501.9 g/s
# Processed: 2630000 | Time: 5239.4s | Speed: 502.0 g/s
# Processed: 2640000 | Time: 5259.0s | Speed: 502.0 g/s
# Processed: 2650000 | Time: 5278.4s | Speed: 502.0 g/s
# Processed: 2660000 | Time: 5298.0s | Speed: 502.1 g/s
# Processed: 2670000 | Time: 5317.5s | Speed: 502.1 g/s
# Processed: 2680000 | Time: 5337.0s | Speed: 502.2 g/s
# Processed: 2690000 | Time: 5356.4s | Speed: 502.2 g/s
# Processed: 2700000 | Time: 5375.8s | Speed: 502.2 g/s
# Processed: 2710000 | Time: 5395.3s | Speed: 502.3 g/s
# Processed: 2720000 | Time: 5414.7s | Speed: 502.3 g/s
# Processed: 2730000 | Time: 5433.9s | Speed: 502.4 g/s
# Processed: 2740000 | Time: 5453.3s | Speed: 502.4 g/s
# Processed: 2750000 | Time: 5472.6s | Speed: 502.5 g/s
# Processed: 2760000 | Time: 5492.4s | Speed: 502.5 g/s
# Processed: 2770000 | Time: 5512.0s | Speed: 502.5 g/s
# Processed: 2780000 | Time: 5531.5s | Speed: 502.6 g/s
# Processed: 2790000 | Time: 5551.1s | Speed: 502.6 g/s
# Processed: 2800000 | Time: 5570.7s | Speed: 502.6 g/s
# Processed: 2810000 | Time: 5590.2s | Speed: 502.7 g/s
# Processed: 2820000 | Time: 5609.6s | Speed: 502.7 g/s
# Processed: 2830000 | Time: 5629.1s | Speed: 502.7 g/s
# Processed: 2840000 | Time: 5648.6s | Speed: 502.8 g/s
# Processed: 2850000 | Time: 5668.0s | Speed: 502.8 g/s
# Processed: 2860000 | Time: 5687.6s | Speed: 502.8 g/s
# Processed: 2870000 | Time: 5707.2s | Speed: 502.9 g/s
# Processed: 2880000 | Time: 5726.7s | Speed: 502.9 g/s
# Processed: 2890000 | Time: 5746.0s | Speed: 503.0 g/s
# Processed: 2900000 | Time: 5765.3s | Speed: 503.0 g/s
# Processed: 2910000 | Time: 5784.5s | Speed: 503.1 g/s
# Processed: 2920000 | Time: 5803.8s | Speed: 503.1 g/s
# Processed: 2930000 | Time: 5823.2s | Speed: 503.2 g/s
# Processed: 2940000 | Time: 5842.6s | Speed: 503.2 g/s
# Processed: 2950000 | Time: 5861.8s | Speed: 503.3 g/s
# Processed: 2960000 | Time: 5881.0s | Speed: 503.3 g/s
# Processed: 2970000 | Time: 5900.5s | Speed: 503.3 g/s
# Processed: 2980000 | Time: 5919.9s | Speed: 503.4 g/s
# Processed: 2990000 | Time: 5939.4s | Speed: 503.4 g/s
# Processed: 3000000 | Time: 5959.0s | Speed: 503.4 g/s
# Processed: 3010000 | Time: 5978.2s | Speed: 503.5 g/s
# Processed: 3020000 | Time: 5997.6s | Speed: 503.5 g/s
# Processed: 3030000 | Time: 6016.9s | Speed: 503.6 g/s
# Processed: 3040000 | Time: 6036.1s | Speed: 503.6 g/s
# Processed: 3050000 | Time: 6055.4s | Speed: 503.7 g/s
# Processed: 3060000 | Time: 6074.8s | Speed: 503.7 g/s
# Processed: 3070000 | Time: 6094.1s | Speed: 503.8 g/s
# Processed: 3080000 | Time: 6113.1s | Speed: 503.8 g/s
# Processed: 3090000 | Time: 6131.1s | Speed: 504.0 g/s
# Processed: 3100000 | Time: 6149.9s | Speed: 504.1 g/s
# Processed: 3110000 | Time: 6169.0s | Speed: 504.1 g/s
# Processed: 3120000 | Time: 6188.2s | Speed: 504.2 g/s
# Processed: 3130000 | Time: 6207.4s | Speed: 504.2 g/s
# Processed: 3140000 | Time: 6226.5s | Speed: 504.3 g/s
# Processed: 3150000 | Time: 6245.7s | Speed: 504.3 g/s
# Processed: 3160000 | Time: 6264.9s | Speed: 504.4 g/s
# Processed: 3170000 | Time: 6284.2s | Speed: 504.4 g/s
# Processed: 3180000 | Time: 6303.4s | Speed: 504.5 g/s
# Processed: 3190000 | Time: 6322.7s | Speed: 504.5 g/s
# Processed: 3200000 | Time: 6341.9s | Speed: 504.6 g/s
# Processed: 3210000 | Time: 6361.1s | Speed: 504.6 g/s
# Processed: 3220000 | Time: 6380.6s | Speed: 504.7 g/s
# Processed: 3230000 | Time: 6399.8s | Speed: 504.7 g/s
# Processed: 3240000 | Time: 6418.9s | Speed: 504.8 g/s
# Processed: 3250000 | Time: 6438.0s | Speed: 504.8 g/s
# Processed: 3260000 | Time: 6457.1s | Speed: 504.9 g/s
# Processed: 3270000 | Time: 6476.2s | Speed: 504.9 g/s
# Processed: 3280000 | Time: 6495.3s | Speed: 505.0 g/s
# Processed: 3290000 | Time: 6514.3s | Speed: 505.0 g/s
# Processed: 3300000 | Time: 6533.3s | Speed: 505.1 g/s
# Processed: 3310000 | Time: 6552.4s | Speed: 505.2 g/s
# Processed: 3320000 | Time: 6571.4s | Speed: 505.2 g/s
# Processed: 3330000 | Time: 6590.6s | Speed: 505.3 g/s
# Processed: 3340000 | Time: 6609.8s | Speed: 505.3 g/s
# Processed: 3350000 | Time: 6629.1s | Speed: 505.4 g/s
# Processed: 3360000 | Time: 6648.4s | Speed: 505.4 g/s
# Processed: 3370000 | Time: 6667.7s | Speed: 505.4 g/s
# Processed: 3380000 | Time: 6687.0s | Speed: 505.5 g/s
# Processed: 3390000 | Time: 6706.1s | Speed: 505.5 g/s
# Processed: 3400000 | Time: 6725.3s | Speed: 505.6 g/s
# Processed: 3410000 | Time: 6744.5s | Speed: 505.6 g/s
# Processed: 3420000 | Time: 6763.7s | Speed: 505.6 g/s
# Processed: 3430000 | Time: 6783.2s | Speed: 505.7 g/s
# Processed: 3440000 | Time: 6802.6s | Speed: 505.7 g/s
# Processed: 3450000 | Time: 6821.9s | Speed: 505.7 g/s
# Processed: 3460000 | Time: 6841.1s | Speed: 505.8 g/s
# Processed: 3470000 | Time: 6860.2s | Speed: 505.8 g/s
# Processed: 3480000 | Time: 6879.2s | Speed: 505.9 g/s
# Processed: 3490000 | Time: 6898.1s | Speed: 505.9 g/s
# Processed: 3500000 | Time: 6917.5s | Speed: 506.0 g/s
# Processed: 3510000 | Time: 6936.6s | Speed: 506.0 g/s
# Processed: 3520000 | Time: 6955.9s | Speed: 506.0 g/s
# Processed: 3530000 | Time: 6975.3s | Speed: 506.1 g/s
# Processed: 3540000 | Time: 6994.6s | Speed: 506.1 g/s
# Processed: 3550000 | Time: 7014.0s | Speed: 506.1 g/s
# Processed: 3560000 | Time: 7033.3s | Speed: 506.2 g/s
# Processed: 3570000 | Time: 7052.6s | Speed: 506.2 g/s
# Processed: 3580000 | Time: 7071.8s | Speed: 506.2 g/s
# Processed: 3590000 | Time: 7090.9s | Speed: 506.3 g/s
# Processed: 3600000 | Time: 7110.1s | Speed: 506.3 g/s
# Processed: 3610000 | Time: 7129.3s | Speed: 506.4 g/s
# Processed: 3620000 | Time: 7148.4s | Speed: 506.4 g/s
# Processed: 3630000 | Time: 7167.7s | Speed: 506.4 g/s
# Processed: 3640000 | Time: 7186.9s | Speed: 506.5 g/s
# Processed: 3650000 | Time: 7206.1s | Speed: 506.5 g/s
# Processed: 3660000 | Time: 7225.3s | Speed: 506.6 g/s
# Processed: 3670000 | Time: 7244.4s | Speed: 506.6 g/s
# Processed: 3680000 | Time: 7263.8s | Speed: 506.6 g/s
# Processed: 3690000 | Time: 7283.1s | Speed: 506.7 g/s
# Processed: 3700000 | Time: 7302.5s | Speed: 506.7 g/s
# Processed: 3710000 | Time: 7321.7s | Speed: 506.7 g/s
# Processed: 3720000 | Time: 7341.2s | Speed: 506.7 g/s
# Processed: 3730000 | Time: 7360.4s | Speed: 506.8 g/s
# Processed: 3740000 | Time: 7379.7s | Speed: 506.8 g/s
# Processed: 3750000 | Time: 7399.3s | Speed: 506.8 g/s
# Processed: 3760000 | Time: 7418.5s | Speed: 506.8 g/s
# Processed: 3770000 | Time: 7437.6s | Speed: 506.9 g/s
# Processed: 3780000 | Time: 7457.1s | Speed: 506.9 g/s
# Processed: 3790000 | Time: 7476.2s | Speed: 506.9 g/s
# Processed: 3800000 | Time: 7495.7s | Speed: 507.0 g/s
# Processed: 3810000 | Time: 7514.9s | Speed: 507.0 g/s
# Processed: 3820000 | Time: 7534.1s | Speed: 507.0 g/s
# Processed: 3830000 | Time: 7553.3s | Speed: 507.1 g/s
# Processed: 3840000 | Time: 7572.6s | Speed: 507.1 g/s
# Processed: 3850000 | Time: 7591.7s | Speed: 507.1 g/s
# Processed: 3860000 | Time: 7610.9s | Speed: 507.2 g/s
# Processed: 3870000 | Time: 7630.3s | Speed: 507.2 g/s
# Processed: 3880000 | Time: 7649.6s | Speed: 507.2 g/s
# Processed: 3890000 | Time: 7668.9s | Speed: 507.2 g/s
# Processed: 3900000 | Time: 7688.1s | Speed: 507.3 g/s
# Processed: 3910000 | Time: 7707.5s | Speed: 507.3 g/s
# Processed: 3920000 | Time: 7726.9s | Speed: 507.3 g/s
# Processed: 3930000 | Time: 7746.0s | Speed: 507.4 g/s
# Processed: 3940000 | Time: 7765.3s | Speed: 507.4 g/s
# Processed: 3950000 | Time: 7784.6s | Speed: 507.4 g/s
# Processed: 3960000 | Time: 7803.9s | Speed: 507.4 g/s
# Processed: 3970000 | Time: 7823.2s | Speed: 507.5 g/s
# Processed: 3980000 | Time: 7842.4s | Speed: 507.5 g/s
# Processed: 3990000 | Time: 7861.8s | Speed: 507.5 g/s
# Processed: 4000000 | Time: 7881.1s | Speed: 507.5 g/s
# Processed: 4010000 | Time: 7900.4s | Speed: 507.6 g/s
# Processed: 4020000 | Time: 7919.5s | Speed: 507.6 g/s
# Processed: 4030000 | Time: 7938.7s | Speed: 507.6 g/s
# Processed: 4040000 | Time: 7957.7s | Speed: 507.7 g/s
# Processed: 4050000 | Time: 7976.8s | Speed: 507.7 g/s
# Processed: 4060000 | Time: 7996.0s | Speed: 507.8 g/s
# Processed: 4070000 | Time: 8015.2s | Speed: 507.8 g/s
# Processed: 4080000 | Time: 8034.5s | Speed: 507.8 g/s
# Processed: 4090000 | Time: 8053.8s | Speed: 507.8 g/s
# Processed: 4100000 | Time: 8073.2s | Speed: 507.9 g/s
# Processed: 4110000 | Time: 8092.5s | Speed: 507.9 g/s
# Processed: 4120000 | Time: 8111.9s | Speed: 507.9 g/s
# Processed: 4130000 | Time: 8131.2s | Speed: 507.9 g/s
# Processed: 4140000 | Time: 8150.7s | Speed: 507.9 g/s
# Processed: 4150000 | Time: 8170.0s | Speed: 508.0 g/s
# Processed: 4160000 | Time: 8189.3s | Speed: 508.0 g/s
# Processed: 4170000 | Time: 8208.7s | Speed: 508.0 g/s
# Processed: 4180000 | Time: 8228.1s | Speed: 508.0 g/s
# Processed: 4190000 | Time: 8247.4s | Speed: 508.0 g/s
# Processed: 4200000 | Time: 8266.6s | Speed: 508.1 g/s
# Processed: 4210000 | Time: 8286.0s | Speed: 508.1 g/s
# Processed: 4220000 | Time: 8305.3s | Speed: 508.1 g/s
# Processed: 4230000 | Time: 8324.6s | Speed: 508.1 g/s
# Processed: 4240000 | Time: 8343.8s | Speed: 508.2 g/s
# Processed: 4250000 | Time: 8363.1s | Speed: 508.2 g/s
# Processed: 4260000 | Time: 8382.3s | Speed: 508.2 g/s
# Processed: 4270000 | Time: 8401.7s | Speed: 508.2 g/s
# Processed: 4280000 | Time: 8421.0s | Speed: 508.3 g/s
# Processed: 4290000 | Time: 8440.3s | Speed: 508.3 g/s
# Processed: 4300000 | Time: 8459.8s | Speed: 508.3 g/s
# Processed: 4310000 | Time: 8479.1s | Speed: 508.3 g/s
# Processed: 4320000 | Time: 8498.2s | Speed: 508.3 g/s
# Processed: 4330000 | Time: 8517.4s | Speed: 508.4 g/s
# Processed: 4340000 | Time: 8536.7s | Speed: 508.4 g/s
# Processed: 4350000 | Time: 8556.1s | Speed: 508.4 g/s
# Processed: 4360000 | Time: 8575.5s | Speed: 508.4 g/s
# Processed: 4370000 | Time: 8595.0s | Speed: 508.4 g/s
# Processed: 4380000 | Time: 8614.3s | Speed: 508.5 g/s
# Processed: 4390000 | Time: 8633.6s | Speed: 508.5 g/s
# Processed: 4400000 | Time: 8652.7s | Speed: 508.5 g/s
# Processed: 4410000 | Time: 8671.8s | Speed: 508.5 g/s
# Processed: 4420000 | Time: 8690.9s | Speed: 508.6 g/s
# Processed: 4430000 | Time: 8710.1s | Speed: 508.6 g/s
# Processed: 4440000 | Time: 8729.4s | Speed: 508.6 g/s
# Processed: 4450000 | Time: 8748.7s | Speed: 508.6 g/s
# Processed: 4460000 | Time: 8768.3s | Speed: 508.7 g/s
# Processed: 4470000 | Time: 8787.4s | Speed: 508.7 g/s
# Processed: 4480000 | Time: 8806.8s | Speed: 508.7 g/s
# Processed: 4490000 | Time: 8826.0s | Speed: 508.7 g/s
# Processed: 4500000 | Time: 8845.4s | Speed: 508.7 g/s
# Processed: 4510000 | Time: 8864.8s | Speed: 508.8 g/s
# Processed: 4520000 | Time: 8884.2s | Speed: 508.8 g/s
# Processed: 4530000 | Time: 8903.6s | Speed: 508.8 g/s
# Processed: 4540000 | Time: 8922.7s | Speed: 508.8 g/s
# Processed: 4550000 | Time: 8942.1s | Speed: 508.8 g/s
# Processed: 4560000 | Time: 8961.3s | Speed: 508.9 g/s
# Processed: 4570000 | Time: 8980.5s | Speed: 508.9 g/s
# Processed: 4580000 | Time: 8999.7s | Speed: 508.9 g/s
# Processed: 4590000 | Time: 9018.7s | Speed: 508.9 g/s
# Processed: 4600000 | Time: 9037.6s | Speed: 509.0 g/s
# Processed: 4610000 | Time: 9056.3s | Speed: 509.0 g/s
# Processed: 4620000 | Time: 9075.5s | Speed: 509.1 g/s
# Processed: 4630000 | Time: 9095.0s | Speed: 509.1 g/s
# Processed: 4640000 | Time: 9114.3s | Speed: 509.1 g/s
# Processed: 4650000 | Time: 9133.6s | Speed: 509.1 g/s
# Processed: 4660000 | Time: 9153.1s | Speed: 509.1 g/s
# Processed: 4670000 | Time: 9172.3s | Speed: 509.1 g/s
# Processed: 4680000 | Time: 9191.8s | Speed: 509.1 g/s
# Processed: 4690000 | Time: 9211.1s | Speed: 509.2 g/s
# Processed: 4700000 | Time: 9230.4s | Speed: 509.2 g/s
# Processed: 4710000 | Time: 9249.9s | Speed: 509.2 g/s
# Processed: 4720000 | Time: 9269.5s | Speed: 509.2 g/s
# Processed: 4730000 | Time: 9288.8s | Speed: 509.2 g/s
# Processed: 4740000 | Time: 9308.0s | Speed: 509.2 g/s
# Processed: 4750000 | Time: 9327.3s | Speed: 509.3 g/s
# Processed: 4760000 | Time: 9346.5s | Speed: 509.3 g/s
# Processed: 4770000 | Time: 9365.8s | Speed: 509.3 g/s
# Processed: 4780000 | Time: 9385.0s | Speed: 509.3 g/s
# Processed: 4790000 | Time: 9404.2s | Speed: 509.3 g/s
# Processed: 4800000 | Time: 9423.3s | Speed: 509.4 g/s
# Processed: 4810000 | Time: 9442.6s | Speed: 509.4 g/s
# Processed: 4820000 | Time: 9461.9s | Speed: 509.4 g/s
# Processed: 4830000 | Time: 9481.1s | Speed: 509.4 g/s
# Processed: 4840000 | Time: 9500.5s | Speed: 509.4 g/s
# Processed: 4850000 | Time: 9519.8s | Speed: 509.5 g/s
# Processed: 4860000 | Time: 9539.0s | Speed: 509.5 g/s
# Processed: 4870000 | Time: 9558.5s | Speed: 509.5 g/s
# Processed: 4880000 | Time: 9577.7s | Speed: 509.5 g/s
# Processed: 4890000 | Time: 9596.9s | Speed: 509.5 g/s
# Processed: 4900000 | Time: 9616.1s | Speed: 509.6 g/s
# Processed: 4910000 | Time: 9635.5s | Speed: 509.6 g/s
# Processed: 4920000 | Time: 9654.7s | Speed: 509.6 g/s
# Processed: 4930000 | Time: 9674.0s | Speed: 509.6 g/s
# Processed: 4940000 | Time: 9693.1s | Speed: 509.6 g/s
# Processed: 4950000 | Time: 9712.3s | Speed: 509.7 g/s
# Processed: 4960000 | Time: 9731.3s | Speed: 509.7 g/s
# Processed: 4970000 | Time: 9750.4s | Speed: 509.7 g/s
# Processed: 4980000 | Time: 9769.5s | Speed: 509.8 g/s
# Processed: 4990000 | Time: 9788.8s | Speed: 509.8 g/s
# Processed: 5000000 | Time: 9807.9s | Speed: 509.8 g/s
# Processed: 5010000 | Time: 9827.1s | Speed: 509.8 g/s
# Processed: 5020000 | Time: 9846.2s | Speed: 509.8 g/s
# Processed: 5030000 | Time: 9865.7s | Speed: 509.8 g/s
# Processed: 5040000 | Time: 9884.9s | Speed: 509.9 g/s
# Processed: 5050000 | Time: 9904.3s | Speed: 509.9 g/s
# Processed: 5060000 | Time: 9923.6s | Speed: 509.9 g/s
# Processed: 5070000 | Time: 9943.0s | Speed: 509.9 g/s
# Processed: 5080000 | Time: 9962.3s | Speed: 509.9 g/s
# Processed: 5090000 | Time: 9981.8s | Speed: 509.9 g/s
# Processed: 5100000 | Time: 10001.2s | Speed: 509.9 g/s
# Processed: 5110000 | Time: 10020.6s | Speed: 509.9 g/s
# Processed: 5120000 | Time: 10040.0s | Speed: 510.0 g/s
# Processed: 5130000 | Time: 10059.1s | Speed: 510.0 g/s
# Processed: 5140000 | Time: 10078.5s | Speed: 510.0 g/s
# Processed: 5150000 | Time: 10097.7s | Speed: 510.0 g/s
# Processed: 5160000 | Time: 10116.9s | Speed: 510.0 g/s
# Processed: 5170000 | Time: 10136.3s | Speed: 510.0 g/s
# Processed: 5180000 | Time: 10155.6s | Speed: 510.1 g/s
# Processed: 5190000 | Time: 10174.9s | Speed: 510.1 g/s
# Processed: 5200000 | Time: 10194.5s | Speed: 510.1 g/s
# Processed: 5210000 | Time: 10214.1s | Speed: 510.1 g/s
# Processed: 5220000 | Time: 10234.0s | Speed: 510.1 g/s
# Processed: 5230000 | Time: 10253.7s | Speed: 510.1 g/s
# Processed: 5240000 | Time: 10273.4s | Speed: 510.1 g/s
# Processed: 5250000 | Time: 10293.2s | Speed: 510.0 g/s
# Processed: 5260000 | Time: 10312.9s | Speed: 510.0 g/s
# Processed: 5270000 | Time: 10332.8s | Speed: 510.0 g/s
# Processed: 5280000 | Time: 10352.6s | Speed: 510.0 g/s
# Processed: 5290000 | Time: 10372.5s | Speed: 510.0 g/s
# Processed: 5300000 | Time: 10392.4s | Speed: 510.0 g/s
# Processed: 5310000 | Time: 10412.0s | Speed: 510.0 g/s
# Processed: 5320000 | Time: 10431.6s | Speed: 510.0 g/s
# Processed: 5330000 | Time: 10451.3s | Speed: 510.0 g/s
# Processed: 5340000 | Time: 10470.8s | Speed: 510.0 g/s
# Processed: 5350000 | Time: 10490.3s | Speed: 510.0 g/s
# Processed: 5360000 | Time: 10510.1s | Speed: 510.0 g/s
# Processed: 5370000 | Time: 10529.7s | Speed: 510.0 g/s
# Processed: 5380000 | Time: 10549.5s | Speed: 510.0 g/s
# Processed: 5390000 | Time: 10569.3s | Speed: 510.0 g/s
# Processed: 5400000 | Time: 10589.1s | Speed: 510.0 g/s
# Processed: 5410000 | Time: 10609.0s | Speed: 509.9 g/s
# Processed: 5420000 | Time: 10628.7s | Speed: 509.9 g/s
# Processed: 5430000 | Time: 10648.6s | Speed: 509.9 g/s
# Processed: 5440000 | Time: 10668.3s | Speed: 509.9 g/s
# Processed: 5450000 | Time: 10688.3s | Speed: 509.9 g/s
# Processed: 5460000 | Time: 10708.3s | Speed: 509.9 g/s
# Processed: 5470000 | Time: 10728.1s | Speed: 509.9 g/s
# Processed: 5480000 | Time: 10747.9s | Speed: 509.9 g/s
# Processed: 5490000 | Time: 10767.6s | Speed: 509.9 g/s
# Processed: 5500000 | Time: 10787.3s | Speed: 509.9 g/s
# Processed: 5510000 | Time: 10806.7s | Speed: 509.9 g/s
# Processed: 5520000 | Time: 10826.5s | Speed: 509.9 g/s
# Processed: 5530000 | Time: 10845.9s | Speed: 509.9 g/s
# Processed: 5540000 | Time: 10865.2s | Speed: 509.9 g/s
# Processed: 5550000 | Time: 10884.4s | Speed: 509.9 g/s
# Processed: 5560000 | Time: 10904.0s | Speed: 509.9 g/s
# Processed: 5570000 | Time: 10923.7s | Speed: 509.9 g/s
# Processed: 5580000 | Time: 10943.4s | Speed: 509.9 g/s
# Processed: 5590000 | Time: 10963.3s | Speed: 509.9 g/s
# Processed: 5600000 | Time: 10983.0s | Speed: 509.9 g/s
# Processed: 5610000 | Time: 11002.7s | Speed: 509.9 g/s
# Processed: 5620000 | Time: 11022.4s | Speed: 509.9 g/s
# Processed: 5630000 | Time: 11042.1s | Speed: 509.9 g/s
# Processed: 5640000 | Time: 11061.7s | Speed: 509.9 g/s
# Processed: 5650000 | Time: 11081.3s | Speed: 509.9 g/s
# Processed: 5660000 | Time: 11101.0s | Speed: 509.9 g/s
# Processed: 5670000 | Time: 11120.7s | Speed: 509.9 g/s
# Processed: 5680000 | Time: 11140.3s | Speed: 509.9 g/s
# Processed: 5690000 | Time: 11159.8s | Speed: 509.9 g/s
# Processed: 5700000 | Time: 11179.3s | Speed: 509.9 g/s
# Processed: 5710000 | Time: 11198.8s | Speed: 509.9 g/s
# Processed: 5720000 | Time: 11218.4s | Speed: 509.9 g/s
# Processed: 5730000 | Time: 11237.9s | Speed: 509.9 g/s
# Processed: 5740000 | Time: 11257.6s | Speed: 509.9 g/s
# Processed: 5750000 | Time: 11277.2s | Speed: 509.9 g/s
# Processed: 5760000 | Time: 11296.8s | Speed: 509.9 g/s
# Processed: 5770000 | Time: 11316.7s | Speed: 509.9 g/s
# Processed: 5780000 | Time: 11336.5s | Speed: 509.9 g/s
# Processed: 5790000 | Time: 11356.4s | Speed: 509.8 g/s
# Processed: 5800000 | Time: 11376.1s | Speed: 509.8 g/s
# Processed: 5810000 | Time: 11395.7s | Speed: 509.8 g/s
# Processed: 5820000 | Time: 11415.4s | Speed: 509.8 g/s
# Processed: 5830000 | Time: 11435.0s | Speed: 509.8 g/s
# Processed: 5840000 | Time: 11454.8s | Speed: 509.8 g/s
# Processed: 5850000 | Time: 11474.3s | Speed: 509.8 g/s
# Processed: 5860000 | Time: 11493.7s | Speed: 509.8 g/s
# Processed: 5870000 | Time: 11513.2s | Speed: 509.9 g/s
# Processed: 5880000 | Time: 11532.5s | Speed: 509.9 g/s
# Processed: 5890000 | Time: 11551.8s | Speed: 509.9 g/s
# Processed: 5900000 | Time: 11571.0s | Speed: 509.9 g/s
# Processed: 5910000 | Time: 11590.4s | Speed: 509.9 g/s
# Processed: 5920000 | Time: 11609.6s | Speed: 509.9 g/s
# Processed: 5930000 | Time: 11628.9s | Speed: 509.9 g/s
# Processed: 5940000 | Time: 11648.3s | Speed: 509.9 g/s
# Processed: 5950000 | Time: 11667.8s | Speed: 509.9 g/s
# Processed: 5960000 | Time: 11687.3s | Speed: 510.0 g/s
# Processed: 5970000 | Time: 11706.8s | Speed: 510.0 g/s
# Processed: 5980000 | Time: 11726.1s | Speed: 510.0 g/s
# Processed: 5990000 | Time: 11745.7s | Speed: 510.0 g/s
# Processed: 6000000 | Time: 11765.1s | Speed: 510.0 g/s
# Processed: 6010000 | Time: 11784.6s | Speed: 510.0 g/s
# Processed: 6020000 | Time: 11804.1s | Speed: 510.0 g/s
# Processed: 6030000 | Time: 11823.5s | Speed: 510.0 g/s
# Processed: 6040000 | Time: 11842.7s | Speed: 510.0 g/s
# Processed: 6050000 | Time: 11862.0s | Speed: 510.0 g/s
# Processed: 6060000 | Time: 11881.6s | Speed: 510.0 g/s
# Processed: 6070000 | Time: 11900.9s | Speed: 510.0 g/s
# Processed: 6080000 | Time: 11920.2s | Speed: 510.1 g/s
# Processed: 6090000 | Time: 11939.5s | Speed: 510.1 g/s
# Processed: 6100000 | Time: 11958.9s | Speed: 510.1 g/s
# Processed: 6110000 | Time: 11978.3s | Speed: 510.1 g/s
# Processed: 6120000 | Time: 11997.7s | Speed: 510.1 g/s
# Processed: 6130000 | Time: 12017.2s | Speed: 510.1 g/s
# Processed: 6140000 | Time: 12036.6s | Speed: 510.1 g/s
# Processed: 6150000 | Time: 12056.0s | Speed: 510.1 g/s
# Processed: 6160000 | Time: 12075.4s | Speed: 510.1 g/s
# Processed: 6170000 | Time: 12094.7s | Speed: 510.1 g/s
# Processed: 6180000 | Time: 12114.1s | Speed: 510.1 g/s
# Processed: 6190000 | Time: 12133.5s | Speed: 510.2 g/s
# Processed: 6200000 | Time: 12152.8s | Speed: 510.2 g/s
# Processed: 6210000 | Time: 12172.2s | Speed: 510.2 g/s
# Processed: 6220000 | Time: 12191.6s | Speed: 510.2 g/s
# Processed: 6230000 | Time: 12210.8s | Speed: 510.2 g/s
# Processed: 6240000 | Time: 12230.1s | Speed: 510.2 g/s
# Processed: 6250000 | Time: 12249.3s | Speed: 510.2 g/s
# Processed: 6260000 | Time: 12268.3s | Speed: 510.3 g/s
# Processed: 6270000 | Time: 12287.3s | Speed: 510.3 g/s
# Processed: 6280000 | Time: 12306.4s | Speed: 510.3 g/s
# Processed: 6290000 | Time: 12325.6s | Speed: 510.3 g/s
# Processed: 6300000 | Time: 12345.0s | Speed: 510.3 g/s
# Processed: 6310000 | Time: 12364.4s | Speed: 510.3 g/s
# Processed: 6320000 | Time: 12383.7s | Speed: 510.3 g/s
# Processed: 6330000 | Time: 12403.0s | Speed: 510.4 g/s
# Processed: 6340000 | Time: 12422.2s | Speed: 510.4 g/s
# Processed: 6350000 | Time: 12441.6s | Speed: 510.4 g/s
# Processed: 6360000 | Time: 12460.9s | Speed: 510.4 g/s
# Processed: 6370000 | Time: 12480.1s | Speed: 510.4 g/s
# Processed: 6380000 | Time: 12499.3s | Speed: 510.4 g/s
# Processed: 6390000 | Time: 12518.4s | Speed: 510.4 g/s
# Processed: 6400000 | Time: 12537.7s | Speed: 510.5 g/s
# Processed: 6410000 | Time: 12557.0s | Speed: 510.5 g/s
# Processed: 6420000 | Time: 12576.1s | Speed: 510.5 g/s
# Processed: 6430000 | Time: 12595.4s | Speed: 510.5 g/s
# Processed: 6440000 | Time: 12614.3s | Speed: 510.5 g/s
# Processed: 6450000 | Time: 12633.5s | Speed: 510.5 g/s
# Processed: 6460000 | Time: 12652.6s | Speed: 510.6 g/s
# Processed: 6470000 | Time: 12671.7s | Speed: 510.6 g/s
# Processed: 6480000 | Time: 12690.9s | Speed: 510.6 g/s
# Processed: 6490000 | Time: 12710.1s | Speed: 510.6 g/s
# Processed: 6500000 | Time: 12729.4s | Speed: 510.6 g/s
# Processed: 6510000 | Time: 12748.7s | Speed: 510.6 g/s
# Processed: 6520000 | Time: 12768.0s | Speed: 510.7 g/s
# Processed: 6530000 | Time: 12787.6s | Speed: 510.7 g/s
# Processed: 6540000 | Time: 12806.8s | Speed: 510.7 g/s
# Processed: 6550000 | Time: 12826.1s | Speed: 510.7 g/s
# Processed: 6560000 | Time: 12845.3s | Speed: 510.7 g/s
# Processed: 6570000 | Time: 12864.7s | Speed: 510.7 g/s
# Processed: 6580000 | Time: 12884.0s | Speed: 510.7 g/s
# Processed: 6590000 | Time: 12903.2s | Speed: 510.7 g/s
# Processed: 6600000 | Time: 12922.3s | Speed: 510.7 g/s
# Processed: 6610000 | Time: 12941.4s | Speed: 510.8 g/s
# Processed: 6620000 | Time: 12960.6s | Speed: 510.8 g/s
# Processed: 6630000 | Time: 12979.7s | Speed: 510.8 g/s
# Processed: 6640000 | Time: 12998.8s | Speed: 510.8 g/s
# Processed: 6650000 | Time: 13017.9s | Speed: 510.8 g/s
# Processed: 6660000 | Time: 13037.0s | Speed: 510.9 g/s
# Processed: 6670000 | Time: 13056.2s | Speed: 510.9 g/s
# Processed: 6680000 | Time: 13075.3s | Speed: 510.9 g/s
# Processed: 6690000 | Time: 13094.8s | Speed: 510.9 g/s
# Processed: 6700000 | Time: 13114.1s | Speed: 510.9 g/s
# Processed: 6710000 | Time: 13133.3s | Speed: 510.9 g/s
# Processed: 6720000 | Time: 13153.1s | Speed: 510.9 g/s
# Processed: 6730000 | Time: 13172.3s | Speed: 510.9 g/s
# Processed: 6740000 | Time: 13191.5s | Speed: 510.9 g/s
# Processed: 6750000 | Time: 13210.7s | Speed: 511.0 g/s
# Processed: 6760000 | Time: 13229.8s | Speed: 511.0 g/s
# Processed: 6770000 | Time: 13248.8s | Speed: 511.0 g/s
# Processed: 6780000 | Time: 13268.2s | Speed: 511.0 g/s
# Processed: 6790000 | Time: 13287.5s | Speed: 511.0 g/s
# Processed: 6800000 | Time: 13306.7s | Speed: 511.0 g/s
# Processed: 6810000 | Time: 13325.9s | Speed: 511.0 g/s
# Processed: 6820000 | Time: 13344.9s | Speed: 511.1 g/s
# Processed: 6830000 | Time: 13364.0s | Speed: 511.1 g/s
# Processed: 6840000 | Time: 13383.1s | Speed: 511.1 g/s
# Processed: 6850000 | Time: 13402.1s | Speed: 511.1 g/s
# Processed: 6860000 | Time: 13421.4s | Speed: 511.1 g/s
# Processed: 6870000 | Time: 13440.5s | Speed: 511.1 g/s
# Processed: 6880000 | Time: 13459.8s | Speed: 511.2 g/s
# Processed: 6890000 | Time: 13479.0s | Speed: 511.2 g/s
# Processed: 6900000 | Time: 13498.3s | Speed: 511.2 g/s
# Processed: 6910000 | Time: 13517.5s | Speed: 511.2 g/s
# Processed: 6920000 | Time: 13536.8s | Speed: 511.2 g/s
# Processed: 6930000 | Time: 13556.1s | Speed: 511.2 g/s
# Processed: 6940000 | Time: 13575.5s | Speed: 511.2 g/s
# Processed: 6950000 | Time: 13594.7s | Speed: 511.2 g/s
# Processed: 6960000 | Time: 13613.9s | Speed: 511.2 g/s
# Processed: 6970000 | Time: 13633.0s | Speed: 511.3 g/s
# Processed: 6980000 | Time: 13652.1s | Speed: 511.3 g/s
# Processed: 6990000 | Time: 13671.2s | Speed: 511.3 g/s
# Processed: 7000000 | Time: 13690.2s | Speed: 511.3 g/s
# Processed: 7010000 | Time: 13709.3s | Speed: 511.3 g/s
# Processed: 7020000 | Time: 13729.2s | Speed: 511.3 g/s
# Processed: 7030000 | Time: 13749.0s | Speed: 511.3 g/s
# Processed: 7040000 | Time: 13768.1s | Speed: 511.3 g/s
# Processed: 7050000 | Time: 13787.2s | Speed: 511.3 g/s
# Processed: 7060000 | Time: 13806.5s | Speed: 511.4 g/s
# Processed: 7070000 | Time: 13825.8s | Speed: 511.4 g/s
# Processed: 7080000 | Time: 13845.0s | Speed: 511.4 g/s
# Processed: 7090000 | Time: 13864.2s | Speed: 511.4 g/s
# Processed: 7100000 | Time: 13883.6s | Speed: 511.4 g/s
# Processed: 7110000 | Time: 13902.8s | Speed: 511.4 g/s
# Processed: 7120000 | Time: 13922.0s | Speed: 511.4 g/s
# Processed: 7130000 | Time: 13941.1s | Speed: 511.4 g/s
# Processed: 7140000 | Time: 13960.4s | Speed: 511.4 g/s
# Processed: 7150000 | Time: 13979.7s | Speed: 511.5 g/s
# Processed: 7160000 | Time: 13998.9s | Speed: 511.5 g/s
# Processed: 7170000 | Time: 14018.3s | Speed: 511.5 g/s
# Processed: 7180000 | Time: 14037.6s | Speed: 511.5 g/s
# Processed: 7190000 | Time: 14056.8s | Speed: 511.5 g/s
# Processed: 7200000 | Time: 14075.9s | Speed: 511.5 g/s
# Processed: 7210000 | Time: 14094.9s | Speed: 511.5 g/s
# Processed: 7220000 | Time: 14114.3s | Speed: 511.5 g/s
# Processed: 7230000 | Time: 14133.5s | Speed: 511.6 g/s
# Processed: 7240000 | Time: 14152.7s | Speed: 511.6 g/s
# Processed: 7250000 | Time: 14172.0s | Speed: 511.6 g/s
# Processed: 7260000 | Time: 14191.3s | Speed: 511.6 g/s
# Processed: 7270000 | Time: 14210.6s | Speed: 511.6 g/s
# Processed: 7280000 | Time: 14229.8s | Speed: 511.6 g/s
# Processed: 7290000 | Time: 14249.1s | Speed: 511.6 g/s
# Processed: 7300000 | Time: 14268.5s | Speed: 511.6 g/s
# Processed: 7310000 | Time: 14287.7s | Speed: 511.6 g/s
# Processed: 7320000 | Time: 14306.9s | Speed: 511.6 g/s
# Processed: 7330000 | Time: 14325.9s | Speed: 511.7 g/s
# Processed: 7340000 | Time: 14345.2s | Speed: 511.7 g/s
# Processed: 7350000 | Time: 14364.4s | Speed: 511.7 g/s
# Processed: 7360000 | Time: 14383.5s | Speed: 511.7 g/s
# Processed: 7370000 | Time: 14402.7s | Speed: 511.7 g/s
# Processed: 7380000 | Time: 14421.8s | Speed: 511.7 g/s
# Processed: 7390000 | Time: 14440.9s | Speed: 511.7 g/s
# Processed: 7400000 | Time: 14459.9s | Speed: 511.8 g/s
# Processed: 7410000 | Time: 14479.1s | Speed: 511.8 g/s
# Processed: 7420000 | Time: 14498.2s | Speed: 511.8 g/s
# Processed: 7430000 | Time: 14517.5s | Speed: 511.8 g/s
# Processed: 7440000 | Time: 14536.7s | Speed: 511.8 g/s
# Processed: 7450000 | Time: 14556.1s | Speed: 511.8 g/s
# Processed: 7460000 | Time: 14575.4s | Speed: 511.8 g/s
# Processed: 7470000 | Time: 14594.8s | Speed: 511.8 g/s
# Processed: 7480000 | Time: 14614.0s | Speed: 511.8 g/s
# Processed: 7490000 | Time: 14633.4s | Speed: 511.8 g/s
# Processed: 7500000 | Time: 14652.8s | Speed: 511.8 g/s
# Processed: 7510000 | Time: 14672.0s | Speed: 511.9 g/s
# Processed: 7520000 | Time: 14691.3s | Speed: 511.9 g/s
# Processed: 7530000 | Time: 14710.7s | Speed: 511.9 g/s
# Processed: 7540000 | Time: 14729.9s | Speed: 511.9 g/s
# Processed: 7550000 | Time: 14749.1s | Speed: 511.9 g/s
# Processed: 7560000 | Time: 14768.4s | Speed: 511.9 g/s
# Processed: 7570000 | Time: 14787.5s | Speed: 511.9 g/s
# Processed: 7580000 | Time: 14806.4s | Speed: 511.9 g/s
# Processed: 7590000 | Time: 14825.5s | Speed: 512.0 g/s
# Processed: 7600000 | Time: 14844.7s | Speed: 512.0 g/s
# Processed: 7610000 | Time: 14863.9s | Speed: 512.0 g/s
# Processed: 7620000 | Time: 14883.2s | Speed: 512.0 g/s
# Processed: 7630000 | Time: 14902.6s | Speed: 512.0 g/s
# Processed: 7640000 | Time: 14921.9s | Speed: 512.0 g/s
# Processed: 7650000 | Time: 14941.4s | Speed: 512.0 g/s
# Processed: 7660000 | Time: 14960.7s | Speed: 512.0 g/s
# Processed: 7670000 | Time: 14980.1s | Speed: 512.0 g/s
# Processed: 7680000 | Time: 14999.5s | Speed: 512.0 g/s
# Processed: 7690000 | Time: 15018.9s | Speed: 512.0 g/s
# Processed: 7700000 | Time: 15038.4s | Speed: 512.0 g/s
# Processed: 7710000 | Time: 15057.8s | Speed: 512.0 g/s
# Processed: 7720000 | Time: 15076.9s | Speed: 512.0 g/s
# Processed: 7730000 | Time: 15096.3s | Speed: 512.0 g/s
# Processed: 7740000 | Time: 15115.6s | Speed: 512.1 g/s
# Processed: 7750000 | Time: 15134.9s | Speed: 512.1 g/s
# Processed: 7760000 | Time: 15153.9s | Speed: 512.1 g/s
# Processed: 7770000 | Time: 15173.2s | Speed: 512.1 g/s
# Processed: 7780000 | Time: 15192.6s | Speed: 512.1 g/s
# Processed: 7790000 | Time: 15211.8s | Speed: 512.1 g/s
# Processed: 7800000 | Time: 15231.1s | Speed: 512.1 g/s
# Processed: 7810000 | Time: 15250.5s | Speed: 512.1 g/s
# Processed: 7820000 | Time: 15270.0s | Speed: 512.1 g/s
# Processed: 7830000 | Time: 15289.4s | Speed: 512.1 g/s
# Processed: 7840000 | Time: 15309.0s | Speed: 512.1 g/s
# Processed: 7850000 | Time: 15328.5s | Speed: 512.1 g/s
# Processed: 7860000 | Time: 15347.9s | Speed: 512.1 g/s
# Processed: 7870000 | Time: 15367.4s | Speed: 512.1 g/s
# Processed: 7880000 | Time: 15386.8s | Speed: 512.1 g/s
# Processed: 7890000 | Time: 15406.3s | Speed: 512.1 g/s
# Processed: 7900000 | Time: 15425.6s | Speed: 512.1 g/s
# Processed: 7910000 | Time: 15444.9s | Speed: 512.1 g/s
# Processed: 7920000 | Time: 15464.4s | Speed: 512.1 g/s
# Processed: 7930000 | Time: 15483.8s | Speed: 512.1 g/s
# Processed: 7940000 | Time: 15503.2s | Speed: 512.2 g/s
# Processed: 7950000 | Time: 15522.5s | Speed: 512.2 g/s
# Processed: 7960000 | Time: 15541.9s | Speed: 512.2 g/s
# Processed: 7970000 | Time: 15561.4s | Speed: 512.2 g/s
# Processed: 7980000 | Time: 15581.0s | Speed: 512.2 g/s
# Processed: 7990000 | Time: 15600.5s | Speed: 512.2 g/s
# Processed: 8000000 | Time: 15620.0s | Speed: 512.2 g/s
# Processed: 8010000 | Time: 15639.6s | Speed: 512.2 g/s
# Processed: 8020000 | Time: 15659.0s | Speed: 512.2 g/s
# Processed: 8030000 | Time: 15678.1s | Speed: 512.2 g/s
# Processed: 8040000 | Time: 15697.6s | Speed: 512.2 g/s
# Processed: 8050000 | Time: 15717.2s | Speed: 512.2 g/s
# Processed: 8060000 | Time: 15736.7s | Speed: 512.2 g/s
# Processed: 8070000 | Time: 15756.4s | Speed: 512.2 g/s
# Processed: 8080000 | Time: 15776.0s | Speed: 512.2 g/s
# Processed: 8090000 | Time: 15795.7s | Speed: 512.2 g/s
# Processed: 8100000 | Time: 15815.2s | Speed: 512.2 g/s
# Processed: 8110000 | Time: 15834.9s | Speed: 512.2 g/s
# Processed: 8120000 | Time: 15854.3s | Speed: 512.2 g/s
# Processed: 8130000 | Time: 15873.8s | Speed: 512.2 g/s
# Processed: 8140000 | Time: 15893.1s | Speed: 512.2 g/s
# Processed: 8150000 | Time: 15912.7s | Speed: 512.2 g/s
# Processed: 8160000 | Time: 15932.3s | Speed: 512.2 g/s
# Processed: 8170000 | Time: 15951.8s | Speed: 512.2 g/s
# Processed: 8180000 | Time: 15971.4s | Speed: 512.2 g/s
# Processed: 8190000 | Time: 15991.4s | Speed: 512.2 g/s
# Processed: 8200000 | Time: 16011.1s | Speed: 512.1 g/s
# Processed: 8210000 | Time: 16030.7s | Speed: 512.1 g/s
# Processed: 8220000 | Time: 16050.3s | Speed: 512.1 g/s
# Processed: 8230000 | Time: 16069.8s | Speed: 512.1 g/s
# Processed: 8240000 | Time: 16089.6s | Speed: 512.1 g/s
# Processed: 8250000 | Time: 16109.2s | Speed: 512.1 g/s
# Processed: 8260000 | Time: 16129.0s | Speed: 512.1 g/s
# Processed: 8270000 | Time: 16148.7s | Speed: 512.1 g/s
# Processed: 8280000 | Time: 16168.3s | Speed: 512.1 g/s
# Processed: 8290000 | Time: 16187.9s | Speed: 512.1 g/s
# Processed: 8300000 | Time: 16207.4s | Speed: 512.1 g/s
# Processed: 8310000 | Time: 16226.7s | Speed: 512.1 g/s
# Processed: 8320000 | Time: 16246.1s | Speed: 512.1 g/s
# Processed: 8330000 | Time: 16265.7s | Speed: 512.1 g/s
# Processed: 8340000 | Time: 16285.2s | Speed: 512.1 g/s
# Processed: 8350000 | Time: 16304.8s | Speed: 512.1 g/s
# Processed: 8360000 | Time: 16324.4s | Speed: 512.1 g/s
# Processed: 8370000 | Time: 16344.0s | Speed: 512.1 g/s
# Processed: 8380000 | Time: 16363.5s | Speed: 512.1 g/s
# Processed: 8390000 | Time: 16383.2s | Speed: 512.1 g/s
# Processed: 8400000 | Time: 16402.8s | Speed: 512.1 g/s
# Processed: 8410000 | Time: 16422.4s | Speed: 512.1 g/s
# Processed: 8420000 | Time: 16442.1s | Speed: 512.1 g/s
# Processed: 8430000 | Time: 16461.8s | Speed: 512.1 g/s
# Processed: 8440000 | Time: 16481.4s | Speed: 512.1 g/s
# Processed: 8450000 | Time: 16501.3s | Speed: 512.1 g/s
# Processed: 8460000 | Time: 16520.8s | Speed: 512.1 g/s
# Processed: 8470000 | Time: 16540.4s | Speed: 512.1 g/s
# Processed: 8480000 | Time: 16559.9s | Speed: 512.1 g/s
# Processed: 8490000 | Time: 16579.4s | Speed: 512.1 g/s
# Processed: 8500000 | Time: 16598.8s | Speed: 512.1 g/s
# Processed: 8510000 | Time: 16618.4s | Speed: 512.1 g/s
# Processed: 8520000 | Time: 16637.9s | Speed: 512.1 g/s
# Processed: 8530000 | Time: 16657.3s | Speed: 512.1 g/s
# Processed: 8540000 | Time: 16676.7s | Speed: 512.1 g/s
# Processed: 8550000 | Time: 16696.5s | Speed: 512.1 g/s
# Processed: 8560000 | Time: 16716.2s | Speed: 512.1 g/s
# Processed: 8570000 | Time: 16736.0s | Speed: 512.1 g/s
# Processed: 8580000 | Time: 16756.0s | Speed: 512.1 g/s
# Processed: 8590000 | Time: 16775.6s | Speed: 512.1 g/s
# Processed: 8600000 | Time: 16795.2s | Speed: 512.1 g/s
# Processed: 8610000 | Time: 16814.8s | Speed: 512.0 g/s
# Processed: 8620000 | Time: 16834.6s | Speed: 512.0 g/s
# Processed: 8630000 | Time: 16854.3s | Speed: 512.0 g/s
# Processed: 8640000 | Time: 16873.9s | Speed: 512.0 g/s
# Processed: 8650000 | Time: 16893.6s | Speed: 512.0 g/s
# Processed: 8660000 | Time: 16913.2s | Speed: 512.0 g/s
# Processed: 8670000 | Time: 16932.8s | Speed: 512.0 g/s
# Processed: 8680000 | Time: 16951.7s | Speed: 512.0 g/s
# Processed: 8690000 | Time: 16971.2s | Speed: 512.0 g/s
# Processed: 8700000 | Time: 16990.7s | Speed: 512.0 g/s
# Processed: 8710000 | Time: 17010.4s | Speed: 512.0 g/s
# Processed: 8720000 | Time: 17030.0s | Speed: 512.0 g/s
# Processed: 8730000 | Time: 17049.5s | Speed: 512.0 g/s
# Processed: 8740000 | Time: 17069.2s | Speed: 512.0 g/s
# Processed: 8750000 | Time: 17088.9s | Speed: 512.0 g/s
# Processed: 8760000 | Time: 17108.5s | Speed: 512.0 g/s
# Processed: 8770000 | Time: 17128.1s | Speed: 512.0 g/s
# Processed: 8780000 | Time: 17147.7s | Speed: 512.0 g/s
# Processed: 8790000 | Time: 17167.4s | Speed: 512.0 g/s
# Processed: 8800000 | Time: 17186.8s | Speed: 512.0 g/s
# Processed: 8810000 | Time: 17206.3s | Speed: 512.0 g/s
# Processed: 8820000 | Time: 17225.8s | Speed: 512.0 g/s
# Processed: 8830000 | Time: 17245.3s | Speed: 512.0 g/s
# Processed: 8840000 | Time: 17264.6s | Speed: 512.0 g/s
# ...
# Processed: 11240000 | Time: 21901.5s | Speed: 513.2 g/s
# Processed: 11250000 | Time: 21920.9s | Speed: 513.2 g/s
# Processed: 11260000 | Time: 21940.4s | Speed: 513.2 g/s
# Processed: 11270000 | Time: 21960.0s | Speed: 513.2 g/s
# Processed: 11280000 | Time: 21979.5s | Speed: 513.2 g/s
# Processed: 11290000 | Time: 21999.2s | Speed: 513.2 g/s
# Processed: 11300000 | Time: 22018.5s | Speed: 513.2 g/s
# Processed: 11310000 | Time: 22038.2s | Speed: 513.2 g/s
# Processed: 11320000 | Time: 22057.8s | Speed: 513.2 g/s
# Processed: 11330000 | Time: 22077.4s | Speed: 513.2 g/s
# Processed: 11340000 | Time: 22097.2s | Speed: 513.2 g/s
# Processed: 11350000 | Time: 22116.8s | Speed: 513.2 g/s
# Processed: 11360000 | Time: 22136.5s | Speed: 513.2 g/s
# Processed: 11370000 | Time: 22156.1s | Speed: 513.2 g/s
# Processed: 11380000 | Time: 22175.7s | Speed: 513.2 g/s
# Processed: 11390000 | Time: 22195.1s | Speed: 513.2 g/s
# Processed: 11400000 | Time: 22214.6s | Speed: 513.2 g/s
# Processed: 11410000 | Time: 22234.0s | Speed: 513.2 g/s
# Processed: 11420000 | Time: 22253.6s | Speed: 513.2 g/s
# Processed: 11430000 | Time: 22273.0s | Speed: 513.2 g/s
# Processed: 11440000 | Time: 22292.5s | Speed: 513.2 g/s
# Processed: 11450000 | Time: 22311.9s | Speed: 513.2 g/s
# Processed: 11460000 | Time: 22331.2s | Speed: 513.2 g/s
# Processed: 11470000 | Time: 22350.7s | Speed: 513.2 g/s
# Processed: 11480000 | Time: 22370.0s | Speed: 513.2 g/s
# Processed: 11490000 | Time: 22389.5s | Speed: 513.2 g/s
# Processed: 11500000 | Time: 22408.8s | Speed: 513.2 g/s
# Processed: 11510000 | Time: 22428.3s | Speed: 513.2 g/s
# Processed: 11520000 | Time: 22447.7s | Speed: 513.2 g/s
# Processed: 11530000 | Time: 22467.3s | Speed: 513.2 g/s
# Processed: 11540000 | Time: 22486.9s | Speed: 513.2 g/s
# Processed: 11550000 | Time: 22506.5s | Speed: 513.2 g/s
# Processed: 11560000 | Time: 22526.1s | Speed: 513.2 g/s
# Processed: 11570000 | Time: 22545.5s | Speed: 513.2 g/s
# Processed: 11580000 | Time: 22565.1s | Speed: 513.2 g/s
# Processed: 11590000 | Time: 22584.5s | Speed: 513.2 g/s
# Processed: 11600000 | Time: 22603.8s | Speed: 513.2 g/s
# Processed: 11610000 | Time: 22623.2s | Speed: 513.2 g/s
# Processed: 11620000 | Time: 22642.5s | Speed: 513.2 g/s
# Processed: 11630000 | Time: 22661.9s | Speed: 513.2 g/s
# Processed: 11640000 | Time: 22681.3s | Speed: 513.2 g/s
# Processed: 11650000 | Time: 22700.9s | Speed: 513.2 g/s
# Processed: 11660000 | Time: 22720.3s | Speed: 513.2 g/s
# Processed: 11670000 | Time: 22739.6s | Speed: 513.2 g/s
# Processed: 11680000 | Time: 22759.1s | Speed: 513.2 g/s
# Processed: 11690000 | Time: 22778.5s | Speed: 513.2 g/s
# Processed: 11700000 | Time: 22798.2s | Speed: 513.2 g/s
# Processed: 11710000 | Time: 22817.8s | Speed: 513.2 g/s
# Processed: 11720000 | Time: 22837.5s | Speed: 513.2 g/s
# Processed: 11730000 | Time: 22857.1s | Speed: 513.2 g/s
# Processed: 11740000 | Time: 22876.8s | Speed: 513.2 g/s
# Processed: 11750000 | Time: 22896.3s | Speed: 513.2 g/s
# Processed: 11760000 | Time: 22916.0s | Speed: 513.2 g/s
# Processed: 11770000 | Time: 22935.6s | Speed: 513.2 g/s
# Processed: 11780000 | Time: 22955.2s | Speed: 513.2 g/s
# Processed: 11790000 | Time: 22974.7s | Speed: 513.2 g/s
# Processed: 11800000 | Time: 22994.1s | Speed: 513.2 g/s
# Processed: 11810000 | Time: 23013.6s | Speed: 513.2 g/s
# Processed: 11820000 | Time: 23033.1s | Speed: 513.2 g/s
# Processed: 11830000 | Time: 23052.5s | Speed: 513.2 g/s
# Processed: 11840000 | Time: 23072.2s | Speed: 513.2 g/s
# Processed: 11850000 | Time: 23091.5s | Speed: 513.2 g/s
# Processed: 11860000 | Time: 23110.9s | Speed: 513.2 g/s
# Processed: 11870000 | Time: 23130.3s | Speed: 513.2 g/s
# Processed: 11880000 | Time: 23149.7s | Speed: 513.2 g/s
# Processed: 11890000 | Time: 23169.2s | Speed: 513.2 g/s
# Processed: 11900000 | Time: 23188.7s | Speed: 513.2 g/s
# Processed: 11910000 | Time: 23208.3s | Speed: 513.2 g/s
# Processed: 11920000 | Time: 23227.7s | Speed: 513.2 g/s
# Processed: 11930000 | Time: 23247.2s | Speed: 513.2 g/s
# Processed: 11940000 | Time: 23266.8s | Speed: 513.2 g/s
# Processed: 11950000 | Time: 23286.3s | Speed: 513.2 g/s
# Processed: 11960000 | Time: 23305.7s | Speed: 513.2 g/s
# Processed: 11970000 | Time: 23325.0s | Speed: 513.2 g/s
# Processed: 11980000 | Time: 23344.4s | Speed: 513.2 g/s
# Processed: 11990000 | Time: 23363.6s | Speed: 513.2 g/s
# Processed: 12000000 | Time: 23382.9s | Speed: 513.2 g/s
# Processed: 12010000 | Time: 23402.2s | Speed: 513.2 g/s
# Processed: 12020000 | Time: 23421.7s | Speed: 513.2 g/s
# Processed: 12030000 | Time: 23440.9s | Speed: 513.2 g/s
# Processed: 12040000 | Time: 23460.2s | Speed: 513.2 g/s
# Processed: 12050000 | Time: 23479.4s | Speed: 513.2 g/s
# Processed: 12060000 | Time: 23498.8s | Speed: 513.2 g/s
# Processed: 12070000 | Time: 23518.2s | Speed: 513.2 g/s
# Processed: 12080000 | Time: 23537.7s | Speed: 513.2 g/s
# Processed: 12090000 | Time: 23557.2s | Speed: 513.2 g/s
# Processed: 12100000 | Time: 23576.6s | Speed: 513.2 g/s
# Processed: 12110000 | Time: 23595.9s | Speed: 513.2 g/s
# Processed: 12120000 | Time: 23615.5s | Speed: 513.2 g/s
# Processed: 12130000 | Time: 23634.5s | Speed: 513.2 g/s
# Processed: 12140000 | Time: 23653.4s | Speed: 513.2 g/s
# Processed: 12150000 | Time: 23672.8s | Speed: 513.2 g/s
# Processed: 12160000 | Time: 23691.9s | Speed: 513.3 g/s
# Processed: 12170000 | Time: 23711.3s | Speed: 513.3 g/s
# Processed: 12180000 | Time: 23730.4s | Speed: 513.3 g/s
# Processed: 12190000 | Time: 23749.3s | Speed: 513.3 g/s
# Processed: 12200000 | Time: 23768.5s | Speed: 513.3 g/s
# Processed: 12210000 | Time: 23787.7s | Speed: 513.3 g/s
# Processed: 12220000 | Time: 23806.8s | Speed: 513.3 g/s
# Processed: 12230000 | Time: 23826.0s | Speed: 513.3 g/s
# Processed: 12240000 | Time: 23845.2s | Speed: 513.3 g/s
# Processed: 12250000 | Time: 23864.4s | Speed: 513.3 g/s
# Processed: 12260000 | Time: 23883.6s | Speed: 513.3 g/s
# Processed: 12270000 | Time: 23902.8s | Speed: 513.3 g/s
# Processed: 12280000 | Time: 23922.2s | Speed: 513.3 g/s
# Processed: 12290000 | Time: 23941.7s | Speed: 513.3 g/s
# Processed: 12300000 | Time: 23961.3s | Speed: 513.3 g/s
# Processed: 12310000 | Time: 23980.6s | Speed: 513.3 g/s
# Processed: 12320000 | Time: 23999.8s | Speed: 513.3 g/s
# Processed: 12330000 | Time: 24019.1s | Speed: 513.3 g/s
# Processed: 12340000 | Time: 24038.3s | Speed: 513.3 g/s
# Processed: 12350000 | Time: 24057.4s | Speed: 513.4 g/s
# Processed: 12360000 | Time: 24076.6s | Speed: 513.4 g/s
# Processed: 12370000 | Time: 24095.7s | Speed: 513.4 g/s
# Processed: 12380000 | Time: 24115.0s | Speed: 513.4 g/s
# Processed: 12390000 | Time: 24133.9s | Speed: 513.4 g/s
# Processed: 12400000 | Time: 24152.8s | Speed: 513.4 g/s
# Processed: 12410000 | Time: 24171.7s | Speed: 513.4 g/s
# Processed: 12420000 | Time: 24190.7s | Speed: 513.4 g/s
# Processed: 12430000 | Time: 24209.8s | Speed: 513.4 g/s
# Processed: 12440000 | Time: 24227.3s | Speed: 513.5 g/s
# Processed: 12450000 | Time: 24246.1s | Speed: 513.5 g/s
# Processed: 12460000 | Time: 24265.5s | Speed: 513.5 g/s
# Processed: 12470000 | Time: 24284.7s | Speed: 513.5 g/s
# Processed: 12480000 | Time: 24303.9s | Speed: 513.5 g/s
# Processed: 12490000 | Time: 24323.0s | Speed: 513.5 g/s
# Processed: 12500000 | Time: 24342.2s | Speed: 513.5 g/s
# Processed: 12510000 | Time: 24361.3s | Speed: 513.5 g/s
# Processed: 12520000 | Time: 24380.6s | Speed: 513.5 g/s
# Processed: 12530000 | Time: 24399.9s | Speed: 513.5 g/s
# Processed: 12540000 | Time: 24419.1s | Speed: 513.5 g/s
# Processed: 12550000 | Time: 24438.3s | Speed: 513.5 g/s
# Processed: 12560000 | Time: 24457.5s | Speed: 513.5 g/s
# Processed: 12570000 | Time: 24476.7s | Speed: 513.6 g/s
# Processed: 12580000 | Time: 24495.6s | Speed: 513.6 g/s
# Processed: 12590000 | Time: 24514.6s | Speed: 513.6 g/s
# Processed: 12600000 | Time: 24533.5s | Speed: 513.6 g/s
# Processed: 12610000 | Time: 24552.6s | Speed: 513.6 g/s
# Processed: 12620000 | Time: 24571.6s | Speed: 513.6 g/s
# Processed: 12630000 | Time: 24590.7s | Speed: 513.6 g/s
# Processed: 12640000 | Time: 24609.9s | Speed: 513.6 g/s
# Processed: 12650000 | Time: 24629.0s | Speed: 513.6 g/s
# Processed: 12660000 | Time: 24648.1s | Speed: 513.6 g/s
# Processed: 12670000 | Time: 24667.3s | Speed: 513.6 g/s
# Processed: 12680000 | Time: 24686.6s | Speed: 513.6 g/s
# Processed: 12690000 | Time: 24705.8s | Speed: 513.6 g/s
# Processed: 12700000 | Time: 24725.0s | Speed: 513.7 g/s
# Processed: 12710000 | Time: 24744.2s | Speed: 513.7 g/s
# Processed: 12720000 | Time: 24763.5s | Speed: 513.7 g/s
# Processed: 12730000 | Time: 24782.7s | Speed: 513.7 g/s
# Processed: 12740000 | Time: 24801.9s | Speed: 513.7 g/s
# Processed: 12750000 | Time: 24821.0s | Speed: 513.7 g/s
# Processed: 12760000 | Time: 24840.1s | Speed: 513.7 g/s
# Processed: 12770000 | Time: 24859.3s | Speed: 513.7 g/s
# Processed: 12780000 | Time: 24878.3s | Speed: 513.7 g/s
# Processed: 12790000 | Time: 24897.4s | Speed: 513.7 g/s
# Processed: 12800000 | Time: 24916.7s | Speed: 513.7 g/s
# Processed: 12810000 | Time: 24935.9s | Speed: 513.7 g/s
# Processed: 12820000 | Time: 24955.3s | Speed: 513.7 g/s
# Processed: 12830000 | Time: 24974.6s | Speed: 513.7 g/s
# Processed: 12840000 | Time: 24995.6s | Speed: 513.7 g/s
# Processed: 12850000 | Time: 25016.2s | Speed: 513.7 g/s
# Processed: 12860000 | Time: 25036.2s | Speed: 513.7 g/s
# Processed: 12870000 | Time: 25055.8s | Speed: 513.7 g/s
# Processed: 12880000 | Time: 25075.7s | Speed: 513.6 g/s
# Processed: 12890000 | Time: 25095.7s | Speed: 513.6 g/s
# Processed: 12900000 | Time: 25115.9s | Speed: 513.6 g/s
# Processed: 12910000 | Time: 25138.7s | Speed: 513.6 g/s
# Processed: 12920000 | Time: 25180.4s | Speed: 513.1 g/s
# Processed: 12930000 | Time: 25222.9s | Speed: 512.6 g/s
# Processed: 12940000 | Time: 25264.6s | Speed: 512.2 g/s
# Processed: 12950000 | Time: 25306.3s | Speed: 511.7 g/s
# Processed: 12960000 | Time: 25343.4s | Speed: 511.4 g/s
# Processed: 12970000 | Time: 25370.9s | Speed: 511.2 g/s
# Processed: 12980000 | Time: 25408.7s | Speed: 510.8 g/s
# Processed: 12990000 | Time: 25437.6s | Speed: 510.7 g/s
# Processed: 13000000 | Time: 25476.6s | Speed: 510.3 g/s
# Processed: 13010000 | Time: 25511.3s | Speed: 510.0 g/s
# Processed: 13020000 | Time: 25534.2s | Speed: 509.9 g/s
# Processed: 13030000 | Time: 25572.3s | Speed: 509.5 g/s
# Processed: 13040000 | Time: 25611.3s | Speed: 509.2 g/s
# Processed: 13050000 | Time: 25650.1s | Speed: 508.8 g/s
# Processed: 13060000 | Time: 25689.8s | Speed: 508.4 g/s
# Processed: 13070000 | Time: 25728.6s | Speed: 508.0 g/s
# Processed: 13080000 | Time: 25767.5s | Speed: 507.6 g/s
# Processed: 13090000 | Time: 25807.7s | Speed: 507.2 g/s
# Processed: 13100000 | Time: 25829.1s | Speed: 507.2 g/s
# Processed: 13110000 | Time: 25849.7s | Speed: 507.2 g/s
# Processed: 13120000 | Time: 25869.8s | Speed: 507.2 g/s
# Processed: 13130000 | Time: 25899.3s | Speed: 507.0 g/s
# Processed: 13140000 | Time: 25942.6s | Speed: 506.5 g/s
# Processed: 13150000 | Time: 25985.0s | Speed: 506.1 g/s
# Processed: 13160000 | Time: 26026.4s | Speed: 505.6 g/s
# Processed: 13170000 | Time: 26070.2s | Speed: 505.2 g/s
# Processed: 13180000 | Time: 26111.4s | Speed: 504.8 g/s
# Processed: 13190000 | Time: 26152.5s | Speed: 504.3 g/s
# Processed: 13200000 | Time: 26196.3s | Speed: 503.9 g/s
# Processed: 13210000 | Time: 26239.5s | Speed: 503.4 g/s
# Processed: 13220000 | Time: 26282.5s | Speed: 503.0 g/s
# Processed: 13230000 | Time: 26319.3s | Speed: 502.7 g/s
# Processed: 13240000 | Time: 26338.5s | Speed: 502.7 g/s
# Processed: 13250000 | Time: 26358.0s | Speed: 502.7 g/s
# Processed: 13260000 | Time: 26377.5s | Speed: 502.7 g/s
# Processed: 13270000 | Time: 26397.0s | Speed: 502.7 g/s
# Processed: 13280000 | Time: 26416.6s | Speed: 502.7 g/s
# Processed: 13290000 | Time: 26436.0s | Speed: 502.7 g/s
# Processed: 13300000 | Time: 26455.8s | Speed: 502.7 g/s
# Processed: 13310000 | Time: 26490.7s | Speed: 502.4 g/s
# Processed: 13320000 | Time: 26532.8s | Speed: 502.0 g/s
# Processed: 13330000 | Time: 26575.2s | Speed: 501.6 g/s
# Processed: 13340000 | Time: 26616.9s | Speed: 501.2 g/s
# Processed: 13350000 | Time: 26661.3s | Speed: 500.7 g/s
# Processed: 13360000 | Time: 26703.1s | Speed: 500.3 g/s
# Processed: 13370000 | Time: 26745.5s | Speed: 499.9 g/s
# Processed: 13380000 | Time: 26789.1s | Speed: 499.5 g/s
# Processed: 13390000 | Time: 26830.9s | Speed: 499.1 g/s
# Processed: 13400000 | Time: 26873.3s | Speed: 498.6 g/s
# Processed: 13410000 | Time: 26917.4s | Speed: 498.2 g/s
# Processed: 13420000 | Time: 26960.5s | Speed: 497.8 g/s
# Processed: 13430000 | Time: 26991.7s | Speed: 497.6 g/s
# Processed: 13440000 | Time: 27033.8s | Speed: 497.2 g/s
# Processed: 13450000 | Time: 27083.1s | Speed: 496.6 g/s
# Processed: 13460000 | Time: 27106.9s | Speed: 496.6 g/s
# Processed: 13470000 | Time: 27129.0s | Speed: 496.5 g/s
# Processed: 13480000 | Time: 27169.9s | Speed: 496.1 g/s
# Processed: 13490000 | Time: 27210.2s | Speed: 495.8 g/s
# Processed: 13500000 | Time: 27249.6s | Speed: 495.4 g/s
# Processed: 13510000 | Time: 27270.0s | Speed: 495.4 g/s
# Processed: 13520000 | Time: 27290.9s | Speed: 495.4 g/s
# Processed: 13530000 | Time: 27315.8s | Speed: 495.3 g/s
# Processed: 13540000 | Time: 27337.0s | Speed: 495.3 g/s
# Processed: 13550000 | Time: 27357.7s | Speed: 495.3 g/s
# Processed: 13560000 | Time: 27384.3s | Speed: 495.2 g/s
# Processed: 13570000 | Time: 27406.1s | Speed: 495.1 g/s
# Processed: 13580000 | Time: 27427.3s | Speed: 495.1 g/s
# Processed: 13590000 | Time: 27448.7s | Speed: 495.1 g/s
# Processed: 13600000 | Time: 27470.6s | Speed: 495.1 g/s
# Processed: 13610000 | Time: 27511.8s | Speed: 494.7 g/s
# Processed: 13620000 | Time: 27551.6s | Speed: 494.3 g/s
# Processed: 13630000 | Time: 27593.1s | Speed: 494.0 g/s
# Processed: 13640000 | Time: 27633.9s | Speed: 493.6 g/s
# Processed: 13650000 | Time: 27674.7s | Speed: 493.2 g/s
# Processed: 13660000 | Time: 27712.2s | Speed: 492.9 g/s
# Processed: 13670000 | Time: 27733.4s | Speed: 492.9 g/s
# Processed: 13680000 | Time: 27761.3s | Speed: 492.8 g/s
# Processed: 13690000 | Time: 27782.1s | Speed: 492.8 g/s
# Processed: 13700000 | Time: 27802.5s | Speed: 492.8 g/s
# Processed: 13710000 | Time: 27823.5s | Speed: 492.7 g/s
# Processed: 13720000 | Time: 27843.9s | Speed: 492.7 g/s
# Processed: 13730000 | Time: 27864.5s | Speed: 492.7 g/s
# Processed: 13740000 | Time: 27885.3s | Speed: 492.7 g/s
# Processed: 13750000 | Time: 27905.6s | Speed: 492.7 g/s
# Processed: 13760000 | Time: 27925.8s | Speed: 492.7 g/s
# Processed: 13770000 | Time: 27946.2s | Speed: 492.7 g/s
# Processed: 13780000 | Time: 27979.2s | Speed: 492.5 g/s
# Processed: 13790000 | Time: 28000.1s | Speed: 492.5 g/s
# Processed: 13800000 | Time: 28020.4s | Speed: 492.5 g/s
# Processed: 13810000 | Time: 28041.9s | Speed: 492.5 g/s
# Processed: 13820000 | Time: 28062.9s | Speed: 492.5 g/s
# Processed: 13830000 | Time: 28088.2s | Speed: 492.4 g/s
# Processed: 13840000 | Time: 28124.9s | Speed: 492.1 g/s
# Processed: 13850000 | Time: 28153.3s | Speed: 492.0 g/s
# Processed: 13860000 | Time: 28194.4s | Speed: 491.6 g/s
# Processed: 13870000 | Time: 28230.3s | Speed: 491.3 g/s
# Processed: 13880000 | Time: 28252.7s | Speed: 491.3 g/s
# Processed: 13890000 | Time: 28288.9s | Speed: 491.0 g/s
# Processed: 13900000 | Time: 28321.3s | Speed: 490.8 g/s
# Processed: 13910000 | Time: 28342.4s | Speed: 490.8 g/s
# Processed: 13920000 | Time: 28362.8s | Speed: 490.8 g/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 241
#     238     print(f"Done! Saved to {FINAL_RESULT_FILE}")
#     240 if __name__ == "__main__":
# --> 241     run_advanced_analysis()
#
# Cell In[1], line 206, in run_advanced_analysis()
#     203 try:
#     204     # 记录这局开始前的偏移量，以便保存
#     205     offset_before_game = pgn_file.tell()
# --> 206     game = chess.pgn.read_game(pgn_file)
#     207 except Exception:
#     208     continue
#
# File d:\Tools\Miniconda\Lib\site-packages\chess\pgn.py:1580, in read_game(handle, Visitor)
#    1578 if consecutive_empty_lines < 1 and line.isspace():
#    1579     consecutive_empty_lines += 1
# -> 1580     line = handle.readline()
#    1581     continue
#    1583 # First token of the game.
#
# File <frozen codecs>:319, in decode(self, input, final)
#
# KeyboardInterrupt:
