# %%
import json 

with open("final_matrix_cpp.json") as f:
    cpp = json.load(f)

with open("final_matrix_py.json") as f:
    pp = json.load(f)
    
print(pp.keys())
print(cpp.keys())
# Out:
# dict_keys(['kill_matrix', 'death_timeline'])
# dict_keys(['death_timeline', 'kill_matrix'])

# %%
# pp["games_processed"] == cpp["games_processed"]

# %%
# tp = pp["stats"]["kill_matrix"]["Black_Bishop_c"]["White_Bishop_f"]
# tp = pp["kill_matrix"]["Black_Bishop_c"]["White_Bishop_f"]

# tc = cpp["stats"]["kill_matrix"]["Black_Bishop_c"]["White_Bishop_f"]
# tc = cpp["kill_matrix"]["Black_Bishop_c"]["White_Bishop_f"]

# %%
ppsk = pp["kill_matrix"]
cpsk = cpp["kill_matrix"]
for x in ppsk.keys():
    for y in ppsk[x]:
        if ppsk[x][y] != cpsk[x][y]:
            print("false at {} -> {} => \n\t ppsk: {}, \n\tcpsk: {}".format(x,y,sum(ppsk[x][y]), sum(cpsk[x][y])))
            # print("false at {} -> {} => \n\t ppsk: {}, \n\tcpsk: {}".format(x,y,1,1))
# Out:
# false at Black_Knight_b -> White_Bishop_c =>
# 	 ppsk: 13,
# 	cpsk: 12
# false at White_Knight_g -> Black_Rook_a =>
# 	 ppsk: 3,
# 	cpsk: 2
# false at White_Bishop_c -> Black_Pawn_c =>
# 	 ppsk: 4,
# 	cpsk: 3
# false at White_Queen -> Black_Queen =>
# 	 ppsk: 46,
# 	cpsk: 45
# false at White_Queen -> Black_Pawn_d =>
# 	 ppsk: 7,
# 	cpsk: 6
# false at Black_Queen -> White_Pawn_a =>
# 	 ppsk: 6,
# 	cpsk: 5
# false at White_Pawn_f -> Black_Pawn_h =>
# 	 ppsk: 5,
# 	cpsk: 4
# false at White_Pawn_b -> Black_Pawn_a =>
# 	 ppsk: 5,
# 	cpsk: 4
# false at Black_King -> White_Knight_g =>
# 	 ppsk: 8,
# 	cpsk: 7
# false at White_Rook_a -> Black_Rook_h =>
# 	 ppsk: 11,
# 	cpsk: 10
# false at White_Rook_a -> Black_Bishop_c =>
# 	 ppsk: 5,
# 	cpsk: 4
# false at Black_Bishop_f -> White_Rook_a =>
# 	 ppsk: 4,
# 	cpsk: 3
# false at Black_Pawn_f -> White_Pawn_e =>
# 	 ppsk: 11,
# 	cpsk: 10
# false at Black_Bishop_c -> White_Queen =>
# 	 ppsk: 8,
# 	cpsk: 7
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 5
#       3 for x in ppsk.keys():
#       4     for y in ppsk[x]:
# ----> 5         if ppsk[x][y] != cpsk[x][y]:
#       6             print("false at {} -> {} => \n\t ppsk: {}, \n\tcpsk: {}".format(x,y,sum(ppsk[x][y]), sum(cpsk[x][y])))
#       7             # print("false at {} -> {} => \n\t ppsk: {}, \n\tcpsk: {}".format(x,y,1,1))
#
# KeyError: 'White_Pawn_b_promoted'

# %%
ppsd = pp["death_timeline"]
cpsd = cpp["death_timeline"]
for x in ppsd.keys():
    if ppsd[x] != cpsd[x]:
        print(sum(ppsd[x]))
        print(sum(cpsd[x]))
# Out:
# 111
# 110
# 118
# 117
# 135
# 134
# 119
# 118
# 49
# 48
# 102
# 101
# 102
# 101
# 49
# 48
# 63
# 62
# 68
# 67
# 76
# 75
# 104
# 103
# 72
# 71
# 56
# 55
# 61
# 60
# 69
# 68
# 55
# 54
# 48
# 47
# 3
# 2
